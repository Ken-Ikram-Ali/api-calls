# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /opt/anaconda3/envs/crewai/lib/python3.11/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/crewai/lib/python3.11/site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/crewai/lib/python3.11/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/crewai/lib/python3.11/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/crewai/lib/python3.11/site-packages (from requests) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Objective API calls

# %% [markdown]
# ### 1. Retrieve List of Collections

# %%
# Accessing collections

import requests

# The URL to access the collection
url = 'https://rest.kendis.io/api/example/collections'
# Your credentials
username = ""  # add kendis username
password = ""  # add kendis key

# Send the GET request with Basic Auth
response = requests.get(url, auth=(username, password))

# Check the response
if response.status_code == 200:
    # Successfully retrieved data
    data = response.json()  # Parse JSON response
    print("Data retrieved successfully:")
    print(data)
else:
    # Handle error
    print(f"Failed to retrieve data. HTTP Status Code: {response.status_code}")
    print("Response content:", response.text)
# Out:
# Data retrieved successfully:
# {'data': [{'id': '64bd1e57e8721807d84464f0', 'title': 'Digital Solutions'}, {'id': '651e6079fa9c6b043ff15a9d', 'title': 'AI Platform'}, {'id': '651e60b4fa9c6b043ff15ad5', 'title': 'Horizon Makers'}, {'id': '677c376cd68a7202535f8a49', 'title': 'Trail Blazers'}, {'id': '62602d8a31a8de672daec42b', 'title': 'Release Train 1 (Sample boards)'}, {'id': '6644475e0852fe7f01d049f3', 'title': 'xyz'}, {'id': '60638b472d6d88585e48c747', 'title': 'Test 1'}, {'id': '6638a04a542065351228cf5f', 'title': 'test'}, {'id': '653aef77e01e487e67bc9161', 'title': 'Data ART'}, {'id': '677c47a4d68a7202535f9599', 'title': 'Lighthouse'}, {'id': '6507f0fd0d71685a3fb19513', 'title': 'Sample Value Stream'}, {'id': '5cec9d67e21b841b49026ce8', 'title': 'Default WorkSpace'}, {'id': '6507f22e0d71685a3fb195a1', 'title': 'Second Value Stream'}, {'id': '662bf3eea6a4a3574cd16158', 'title': 'Jira Portfolio'}, {'id': '600dcf031dfe14721de1c8cb', 'title': 'Demo ART'}, {'id': '616d7de87c6605120cd0dcf1', 'title': 'For Analytics Testing'}]}

# %%
data['data']
# Out:
# [{'id': '64bd1e57e8721807d84464f0', 'title': 'Digital Solutions'},
#  {'id': '651e6079fa9c6b043ff15a9d', 'title': 'AI Platform'},
#  {'id': '651e60b4fa9c6b043ff15ad5', 'title': 'Horizon Makers'},
#  {'id': '677c376cd68a7202535f8a49', 'title': 'Trail Blazers'},
#  {'id': '62602d8a31a8de672daec42b',
#   'title': 'Release Train 1 (Sample boards)'},
#  {'id': '6644475e0852fe7f01d049f3', 'title': 'xyz'},
#  {'id': '60638b472d6d88585e48c747', 'title': 'Test 1'},
#  {'id': '6638a04a542065351228cf5f', 'title': 'test'},
#  {'id': '653aef77e01e487e67bc9161', 'title': 'Data ART'},
#  {'id': '677c47a4d68a7202535f9599', 'title': 'Lighthouse'},
#  {'id': '6507f0fd0d71685a3fb19513', 'title': 'Sample Value Stream'},
#  {'id': '5cec9d67e21b841b49026ce8', 'title': 'Default WorkSpace'},
#  {'id': '6507f22e0d71685a3fb195a1', 'title': 'Second Value Stream'},
#  {'id': '662bf3eea6a4a3574cd16158', 'title': 'Jira Portfolio'},
#  {'id': '600dcf031dfe14721de1c8cb', 'title': 'Demo ART'},
#  {'id': '616d7de87c6605120cd0dcf1', 'title': 'For Analytics Testing'}]

# %% [markdown]
# ### 2. Retrieve List of Boards

# %%
# Retrieve List of Boards

import requests

url = 'https://rest.kendis.io/api/example/boards?collectionId=64bd1e57e8721807d84464f0'

# Send the GET request with Basic Auth
response = requests.get(url, auth=(username, password))

# Check the response
if response.status_code == 200:
    # Successfully retrieved data
    list_of_boards_data = response.json()  # Parse JSON response
    print("Data retrieved successfully:")
    print(list_of_boards_data)
else:
    # Handle error
    print(f"Failed to retrieve data. HTTP Status Code: {response.status_code}")
    print("Response content:", response.text)
# Out:
# Data retrieved successfully:
# {'data': [{'id': '5cec9f1fe21b841b49026d5f', 'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'}, 'title': 'Empty Board'}, {'id': '5dc08f03e21b8461f908ea6e', 'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'}, 'title': 'Demo PI-4 Board'}, {'id': '5df017923883d462067a79b3', 'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'}, 'title': 'PI#4 Planning Board'}, {'id': '5f4e1ceb243ce91629f179ea', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'}, 'title': 'TFS Load Test 1.0'}, {'id': '5fd148371a1fbe144cfbcc23', 'state': {'id': '5cec9d67e21b841b49026cf8', 'title': 'Tracking'}, 'title': 'PI#6 - RT'}, {'id': '606e05c2601e4508eec54cde', 'state': {'id': '5cec9d67e21b841b49026cf8', 'title': 'Tracking'}, 'title': 'WebStore PI#4'}, {'id': '61092cd3ffc77173202d3d90', 'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'}, 'title': 'Practice Demo for Closed'}, {'id': '61bc64ea9d77c43e430deba2', 'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'}, 'title': 'PI#4 Demo Copy'}, {'id': '62a2018603f85b7468e6f626', 'state': {'id': '5cec9d67e21b841b49026cf6', 'title': 'Planning'}, 'title': 'Kendis Only Sample'}, {'id': '640334a5e36d3f2bfb5e02ef', 'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'}, 'title': 'PI#4 Webstore (new)'}, {'id': '641094c0a731f20bb28ab7bf', 'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'}, 'title': 'My Demo PI5'}, {'id': '646c9015275c4601d98960d0', 'state': {'id': '5cec9d67e21b841b49026cf6', 'title': 'Planning'}, 'title': 'PI#5'}, {'id': '6486db375e45f21ea878336e', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'}, 'title': 'Capabilities Views 2023'}, {'id': '64cbd8fa2b799c2f625aae46', 'state': {'id': '5cec9d67e21b841b49026cf8', 'title': 'Tracking'}, 'title': 'PI#8 - Systems ART'}, {'id': '64de1fab5f917313cdd7be2c', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'}, 'title': 'PI#8 - RT'}, {'id': '64fb020843eac0399fe9f287', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'}, 'title': 'Epic-Level Test'}, {'id': '6513d50d013441637c67a543', 'state': {'id': '5cec9d67e21b841b49026cf8', 'title': 'Tracking'}, 'title': 'PI#16 Planning'}, {'id': '653a7c9ce01e487e67bc318d', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'}, 'title': 'Portfolio Epic Board'}, {'id': '653a7d74e01e487e67bc3321', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'}, 'title': 'PI Roadmap'}, {'id': '659db4916fbb8d45738fa74d', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'}, 'title': 'test bulk'}, {'id': '659e53ba6fbb8d45738fe50f', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'}, 'title': 'test bulk 2'}, {'id': '65b38aac8aec043ab8958cb9', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'}, 'title': 'Showing demo'}, {'id': '65e7342e02bb6b6a98159072', 'state': {'id': '5cec9d67e21b841b49026cf8', 'title': 'Tracking'}, 'title': 'PI#7 Obj check'}, {'id': '65eaf305f6983a3970be7ee2', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'}, 'title': 'new copy test'}, {'id': '65f44bc9e7f2c004a43b6603', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'}, 'title': 'Replica PI#9'}, {'id': '661e8c868cb4052afd8994b8', 'state': {'id': '5cec9d67e21b841b49026cf8', 'title': 'Tracking'}, 'title': 'PI#9'}, {'id': '661faeaa06482a309a1651a0', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'}, 'title': 'PI#10'}, {'id': '6627ac7af991ec2bcc155ad9', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'}, 'title': 'Sample 1'}, {'id': '663a2cdceb33692f9f10c652', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'}, 'title': 'test'}, {'id': '663b6886eb33692f9f11aa5c', 'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'}, 'title': 'Test Board 1'}, {'id': '663b997eeb33692f9f11fa55', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'}, 'title': 'PI-17-New'}, {'id': '6679bb746eda6a01e4828d91', 'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},  ...

# %%
list_of_boards_data['data']
# Out:
# [{'id': '5cec9f1fe21b841b49026d5f',
#   'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'},
#   'title': 'Empty Board'},
#  {'id': '5dc08f03e21b8461f908ea6e',
#   'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'},
#   'title': 'Demo PI-4 Board'},
#  {'id': '5df017923883d462067a79b3',
#   'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'},
#   'title': 'PI#4 Planning Board'},
#  {'id': '5f4e1ceb243ce91629f179ea',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'TFS Load Test 1.0'},
#  {'id': '5fd148371a1fbe144cfbcc23',
#   'state': {'id': '5cec9d67e21b841b49026cf8', 'title': 'Tracking'},
#   'title': 'PI#6 - RT'},
#  {'id': '606e05c2601e4508eec54cde',
#   'state': {'id': '5cec9d67e21b841b49026cf8', 'title': 'Tracking'},
#   'title': 'WebStore PI#4'},
#  {'id': '61092cd3ffc77173202d3d90',
#   'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'},
#   'title': 'Practice Demo for Closed'},
#  {'id': '61bc64ea9d77c43e430deba2',
#   'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'},
#   'title': 'PI#4 Demo Copy'},
#  {'id': '62a2018603f85b7468e6f626',
#   'state': {'id': '5cec9d67e21b841b49026cf6', 'title': 'Planning'},
#   'title': 'Kendis Only Sample'},
#  {'id': '640334a5e36d3f2bfb5e02ef',
#   'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'},
#   'title': 'PI#4 Webstore (new)'},
#  {'id': '641094c0a731f20bb28ab7bf',
#   'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'},
#   'title': 'My Demo PI5'},
#  {'id': '646c9015275c4601d98960d0',
#   'state': {'id': '5cec9d67e21b841b49026cf6', 'title': 'Planning'},
#   'title': 'PI#5'},
#  {'id': '6486db375e45f21ea878336e',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'Capabilities Views 2023'},
#  {'id': '64cbd8fa2b799c2f625aae46',
#   'state': {'id': '5cec9d67e21b841b49026cf8', 'title': 'Tracking'},
#   'title': 'PI#8 - Systems ART'},
#  {'id': '64de1fab5f917313cdd7be2c',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'PI#8 - RT'},
#  {'id': '64fb020843eac0399fe9f287',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'Epic-Level Test'},
#  {'id': '6513d50d013441637c67a543',
#   'state': {'id': '5cec9d67e21b841b49026cf8', 'title': 'Tracking'},
#   'title': 'PI#16 Planning'},
#  {'id': '653a7c9ce01e487e67bc318d',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'Portfolio Epic Board'},
#  {'id': '653a7d74e01e487e67bc3321',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'PI Roadmap'},
#  {'id': '659db4916fbb8d45738fa74d',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'test bulk'},
#  {'id': '659e53ba6fbb8d45738fe50f',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'test bulk 2'},
#  {'id': '65b38aac8aec043ab8958cb9',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'Showing demo'},
#  {'id': '65e7342e02bb6b6a98159072',
#   'state': {'id': '5cec9d67e21b841b49026cf8', 'title': 'Tracking'},
#   'title': 'PI#7 Obj check'},
#  {'id': '65eaf305f6983a3970be7ee2',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'new copy test'},
#  {'id': '65f44bc9e7f2c004a43b6603',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'Replica PI#9'},
#  {'id': '661e8c868cb4052afd8994b8',
#   'state': {'id': '5cec9d67e21b841b49026cf8', 'title': 'Tracking'},
#   'title': 'PI#9'},
#  {'id': '661faeaa06482a309a1651a0',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'PI#10'},
#  {'id': '6627ac7af991ec2bcc155ad9',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'Sample 1'},
#  {'id': '663a2cdceb33692f9f10c652',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'test'},
#  {'id': '663b6886eb33692f9f11aa5c',
#   'state': {'id': '5cec9d67e21b841b49026cfa', 'title': 'Close'},
#   'title': 'Test Board 1'},
#  {'id': '663b997eeb33692f9f11fa55',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'PI-17-New'},
#  {'id': '6679bb746eda6a01e4828d91',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'PI#9 Systems ART'},
#  {'id': '66a7f4da2d4f9e11e43b77c3',
#   'state': {'id': '5cec9d67e21b841b49026cf8', 'title': 'Tracking'},
#   'title': 'PI#17'},
#  {'id': '66a801d82d4f9e11e43b8aef',
#   'state': {'id': '5cec9d67e21b841b49026cf8', 'title': 'Tracking'},
#   'title': 'PI#9 - Systems'},
#  {'id': '66ebb6eb5532791ff6cc0d98',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'PI#10'},
#  {'id': '66ebc0985532791ff6cc1cbf',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'PI#10_COPY'},
#  {'id': '66ed18e3309198249670c085',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'PI#18'},
#  {'id': '66f122f01f841d5ae85ff638',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'PI#10'},
#  {'id': '66f260911f841d5ae8617437',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'PI#16_CPY'},
#  {'id': '66fd40ae19dcc43be438ee95',
#   'state': {'id': '5cec9d67e21b841b49026cf8', 'title': 'Tracking'},
#   'title': 'PI17-DBs'},
#  {'id': '66fd499919dcc43be43909ec',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'Kendis Only converted'},
#  {'id': '6756b1b0216f0c3a2bb8ae6e',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'PI#9 DBs'},
#  {'id': '677d9eda638d74022616bccc',
#   'state': {'id': '5cec9d67e21b841b49026cf4', 'title': 'Draft'},
#   'title': 'PI#18'}]

# %% [markdown]
# ### 3. Retrieve List of Objective Groups

# %%
# 2. Retrieve List of Objective Groups

import requests

# API endpoint
url = "https://rest.kendis.io/api/example/objective-groups?boardId=66a7f4da2d4f9e11e43b77c3"

# Send the GET request with Basic Auth
response = requests.get(url, auth=(username, password))

# Check the response
if response.status_code == 200:
    # Successfully retrieved data
    objective_group_data = response.json()  # Parse JSON response
    print("Data retrieved successfully:")
    print(data)
else:
    # Handle error
    print(f"Failed to retrieve data. HTTP Status Code: {response.status_code}")
    print("Response content:", response.text)
# Out:
# Data retrieved successfully:
# {'data': [{'completion': 41.67, 'bvPlan': 28.0, 'bvActual': 3.0, 'achievement': 10.71, 'objectives': [{'completion': 0.0, 'bvPlan': 7.0, 'bvActual': 3.0, 'title': 'Improve DWH nightly sync time by 35%', 'type': 'Objective-Committed', 'sequence': 189061133.0, 'linkedItems': [{'jiraIssueTypeId': '10000', 'storyPoints': 64.0, 'completion': 0.0, 'jiraKey': 'FEA-18', 'originItemId': '66a7f6df2d4f9e11e43b7de7', 'teamsAndSprints': [{'sequence': 72544109403.0, 'sprint': {'id': '66a7f83d2d4f9e11e43b81d5', 'label': 'S3', 'title': 'Sprint 3', 'isIPSprint': False}, 'team': {'color': '#336e7b', 'id': '5e77d14634704051634d110f', 'label': 'SKY', 'title': 'Team Sky'}}, {'sequence': 72544109403.0, 'sprint': {'id': '66a7f83d2d4f9e11e43b81d4', 'label': 'S2', 'title': 'Sprint 2', 'isIPSprint': False}, 'team': {'color': '#6b47db', 'id': '5cec9ee5e21b841b49026d58', 'label': 'DWH', 'title': 'Team DWH'}}, {'sequence': 72544109403.0, 'sprint': {'id': '66a7f83d2d4f9e11e43b81d3', 'label': 'S1', 'title': 'Sprint 1', 'isIPSprint': False}, 'team': {'color': '#e87e04', 'id': '5cec9edae21b841b49026d57', 'label': 'CRM', 'title': 'Team CRM'}}, {'sequence': 72544109403.0, 'sprint': {'id': '66a7f83d2d4f9e11e43b81d3', 'label': 'S1', 'title': 'Sprint 1', 'isIPSprint': False}, 'team': {'color': '#6b47db', 'id': '5cec9ee5e21b841b49026d58', 'label': 'DWH', 'title': 'Team DWH'}}, {'sequence': 72544109403.0, 'sprint': {'id': '66a7f83d2d4f9e11e43b81d5', 'label': 'S3', 'title': 'Sprint 3', 'isIPSprint': False}, 'team': {'color': '#6b47db', 'id': '5cec9ee5e21b841b49026d58', 'label': 'DWH', 'title': 'Team DWH'}}, {'sequence': 72544109403.0, 'sprint': {'id': '66a7f83d2d4f9e11e43b81d6', 'label': 'S4', 'title': 'Sprint 4', 'isIPSprint': False}, 'team': {'color': '#6b47db', 'id': '5cec9ee5e21b841b49026d58', 'label': 'DWH', 'title': 'Team DWH'}}, {'sequence': 72544109403.0, 'sprint': {'id': '66a7f83d2d4f9e11e43b81d6', 'label': 'S4', 'title': 'Sprint 4', 'isIPSprint': False}, 'team': {'color': '#e87e04', 'id': '5cec9edae21b841b49026d57', 'label': 'CRM', 'title': 'Team CRM'}}, {'sequence': 72544109403.0, 'sprint': {'id': '66a7f83d2d4f9e11e43b81d4', 'label': 'S2', 'title': 'Sprint 2', 'isIPSprint': False}, 'team': {'color': '#336e7b', 'id': '5e77d14634704051634d110f', 'label': 'SKY', 'title': 'Team Sky'}}], 'title': 'Nightly Sync from New to older DWH for Reporting', 'type': 'Feature', 'issueType': 'Feature', 'externalReferenceURL': 'javascript:void(0);', 'subItems': [{'jiraIssueTypeId': '10001', 'storyPoints': 8.0, 'jiraKey': 'VEN-5', 'originItemId': '66a7f6df2d4f9e11e43b7dee', 'teamsAndSprints': [{'sequence': 72544110009.0, 'sprint': {'id': '66a7f83d2d4f9e11e43b81d4', 'label': 'S2', 'title': 'Sprint 2', 'isIPSprint': False}, 'team': {'color': '#336e7b', 'id': '5e77d14634704051634d110f', 'label': 'SKY', 'title': 'Team Sky'}}], 'title': 'Multiple adds scenario', 'type': 'UserStory', 'issueType': 'Story', 'jiraId': '10241', 'id': '66a7f83e2d4f9e11e43b8252', 'status': {'id': '66a7f4dd2d4f9e11e43b7965', 'title': 'To Do', 'category': 'ToDo'}}, {'jiraIssueTypeId': '10001', 'storyPoints': 5.0, 'jiraKey': 'VEN-4', 'originItemId': '66a7f6df2d4f9e11e43b7df0', 'teamsAndSprints': [{'sequence': 72544110009.0, 'sprint': {'id': '66a7f83d2d4f9e11e43b81d5', 'label': 'S3', 'title': 'Sprint 3', 'isIPSprint': False}, 'team': {'color': '#336e7b', 'id': '5e77d14634704051634d110f', 'label': 'SKY', 'title': 'Team Sky'}}], 'title': 'DWH reporting updates for CRM 1', 'type': 'UserStory', 'issueType': 'Story', 'jiraId': '10240', 'id': '66a7f83e2d4f9e11e43b8253', 'status': {'id': '66a7f4dd2d4f9e11e43b7963', 'title': 'In Progress', 'category': 'InProgress'}}, {'jiraIssueTypeId': '10004', 'storyPoints': 0.0, 'jiraKey': 'MARS-71', 'originItemId': '66a7f6df2d4f9e11e43b7e03', 'teamsAndSprints': [{'sequence': 72544110009.0, 'sprint': {'id': '66a7f83d2d4f9e11e43b81d4', 'label': 'S2', 'title': 'Sprint 2', 'isIPSprint': False}, 'team': {'color': '#6b47db', 'id': '5cec9ee5e21b841b49026d58', 'label': 'DWH', 'title': ' ...

# %%
objective_group_data['data']
# Out:
# [{'completion': 41.67,
#   'bvPlan': 28.0,
#   'bvActual': 3.0,
#   'achievement': 10.71,
#   'objectives': [{'completion': 0.0,
#     'bvPlan': 7.0,
#     'bvActual': 3.0,
#     'title': 'Improve DWH nightly sync time by 35%',
#     'type': 'Objective-Committed',
#     'sequence': 189061133.0,
#     'linkedItems': [{'jiraIssueTypeId': '10000',
#       'storyPoints': 64.0,
#       'completion': 0.0,
#       'jiraKey': 'FEA-18',
#       'originItemId': '66a7f6df2d4f9e11e43b7de7',
#       'teamsAndSprints': [{'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#          'label': 'S3',
#          'title': 'Sprint 3',
#          'isIPSprint': False},
#         'team': {'color': '#336e7b',
#          'id': '5e77d14634704051634d110f',
#          'label': 'SKY',
#          'title': 'Team Sky'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#          'label': 'S2',
#          'title': 'Sprint 2',
#          'isIPSprint': False},
#         'team': {'color': '#6b47db',
#          'id': '5cec9ee5e21b841b49026d58',
#          'label': 'DWH',
#          'title': 'Team DWH'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#          'label': 'S1',
#          'title': 'Sprint 1',
#          'isIPSprint': False},
#         'team': {'color': '#e87e04',
#          'id': '5cec9edae21b841b49026d57',
#          'label': 'CRM',
#          'title': 'Team CRM'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#          'label': 'S1',
#          'title': 'Sprint 1',
#          'isIPSprint': False},
#         'team': {'color': '#6b47db',
#          'id': '5cec9ee5e21b841b49026d58',
#          'label': 'DWH',
#          'title': 'Team DWH'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#          'label': 'S3',
#          'title': 'Sprint 3',
#          'isIPSprint': False},
#         'team': {'color': '#6b47db',
#          'id': '5cec9ee5e21b841b49026d58',
#          'label': 'DWH',
#          'title': 'Team DWH'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d6',
#          'label': 'S4',
#          'title': 'Sprint 4',
#          'isIPSprint': False},
#         'team': {'color': '#6b47db',
#          'id': '5cec9ee5e21b841b49026d58',
#          'label': 'DWH',
#          'title': 'Team DWH'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d6',
#          'label': 'S4',
#          'title': 'Sprint 4',
#          'isIPSprint': False},
#         'team': {'color': '#e87e04',
#          'id': '5cec9edae21b841b49026d57',
#          'label': 'CRM',
#          'title': 'Team CRM'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#          'label': 'S2',
#          'title': 'Sprint 2',
#          'isIPSprint': False},
#         'team': {'color': '#336e7b',
#          'id': '5e77d14634704051634d110f',
#          'label': 'SKY',
#          'title': 'Team Sky'}}],
#       'title': 'Nightly Sync from New to older DWH for Reporting',
#       'type': 'Feature',
#       'issueType': 'Feature',
#       'externalReferenceURL': 'javascript:void(0);',
#       'subItems': [{'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'VEN-5',
#         'originItemId': '66a7f6df2d4f9e11e43b7dee',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#336e7b',
#            'id': '5e77d14634704051634d110f',
#            'label': 'SKY',
#            'title': 'Team Sky'}}],
#         'title': 'Multiple adds scenario',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10241',
#         'id': '66a7f83e2d4f9e11e43b8252',
#         'status': {'id': '66a7f4dd2d4f9e11e43b7965',
#          'title': 'To Do',
#          'category': 'ToDo'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'VEN-4',
#         'originItemId': '66a7f6df2d4f9e11e43b7df0',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#            'label': 'S3',
#            'title': 'Sprint 3',
#            'isIPSprint': False},
#           'team': {'color': '#336e7b',
#            'id': '5e77d14634704051634d110f',
#            'label': 'SKY',
#            'title': 'Team Sky'}}],
#         'title': 'DWH reporting updates for CRM 1',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10240',
#         'id': '66a7f83e2d4f9e11e43b8253',
#         'status': {'id': '66a7f4dd2d4f9e11e43b7963',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10004',
#         'storyPoints': 0.0,
#         'jiraKey': 'MARS-71',
#         'originItemId': '66a7f6df2d4f9e11e43b7e03',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'CLONE - DWH checks missing',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10496',
#         'id': '66a7f83e2d4f9e11e43b825b',
#         'status': {'id': '66a7f4dc2d4f9e11e43b792b',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10004',
#         'jiraKey': 'MARS-68',
#         'originItemId': '66a7f6df2d4f9e11e43b7e08',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#            'label': 'S3',
#            'title': 'Sprint 3',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'DWH checks missing',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10488',
#         'id': '66a7f83e2d4f9e11e43b825c',
#         'status': {'id': '66a7f4dc2d4f9e11e43b792b',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10004',
#         'storyPoints': 0.0,
#         'jiraKey': 'MARS-67',
#         'originItemId': '66a7f6df2d4f9e11e43b7e09',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'CSS issue',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10487',
#         'id': '66a7f83e2d4f9e11e43b825d',
#         'status': {'id': '66a7f4dc2d4f9e11e43b792b',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10004',
#         'jiraKey': 'MARS-66',
#         'originItemId': '66a7f6df2d4f9e11e43b7e0a',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'Another',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10486',
#         'id': '66a7f83e2d4f9e11e43b825e',
#         'status': {'id': '66a7f4dc2d4f9e11e43b792b',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'MARS-44',
#         'originItemId': '66a7f6df2d4f9e11e43b7e16',
#         'title': 'Test 2',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10384',
#         'id': '66a7f83e2d4f9e11e43b8264',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7927',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 0.0,
#         'jiraKey': 'MARS-43',
#         'originItemId': '66a7f6df2d4f9e11e43b7e17',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d6',
#            'label': 'S4',
#            'title': 'Sprint 4',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'My WB test',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10381',
#         'id': '66a7f83e2d4f9e11e43b8265',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'MARS-39',
#         'originItemId': '66a7f6df2d4f9e11e43b7e1a',
#         'title': 'New Story for SP2',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10373',
#         'id': '66a7f83e2d4f9e11e43b8268',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 0.0,
#         'jiraKey': 'JUP-24',
#         'originItemId': '66a7f6df2d4f9e11e43b7e38',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#            'label': 'S1',
#            'title': 'Sprint 1',
#            'isIPSprint': False},
#           'team': {'color': '#e87e04',
#            'id': '5cec9edae21b841b49026d57',
#            'label': 'CRM',
#            'title': 'Team CRM'}}],
#         'title': 'Synchronization Phase 1',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10386',
#         'id': '66a7f83e2d4f9e11e43b8282',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7945',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'JUP-19',
#         'originItemId': '66a7f6df2d4f9e11e43b7e3b',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#            'label': 'S3',
#            'title': 'Sprint 3',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'System checks',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10355',
#         'id': '66a7f83e2d4f9e11e43b8286',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7943',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 13.0,
#         'jiraKey': 'JUP-15',
#         'originItemId': '66a7f6df2d4f9e11e43b7e3d',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d6',
#            'label': 'S4',
#            'title': 'Sprint 4',
#            'isIPSprint': False},
#           'team': {'color': '#e87e04',
#            'id': '5cec9edae21b841b49026d57',
#            'label': 'CRM',
#            'title': 'Team CRM'}}],
#         'title': 'Story 5',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10333',
#         'id': '66a7f83e2d4f9e11e43b8287',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7943',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 4.0,
#         'jiraKey': 'MARS-199',
#         'title': 'gang',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10910',
#         'id': '671f7190f1295970b0f23503',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7927',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 4.0,
#         'jiraKey': 'MARS-200',
#         'title': 'bala',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10911',
#         'id': '671f71a0af47151e0f4a87d4',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7927',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 4.0,
#         'jiraKey': 'MARS-201',
#         'title': 'gaadi',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10912',
#         'id': '671f71b1af47151e0f4a87ff',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7927',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 3.0,
#         'jiraKey': 'MARS-202',
#         'title': 'pati',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10913',
#         'id': '671f71b2dec74417c3c18d3f',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7927',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'MARS-219',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#            'label': 'S1',
#            'title': 'Sprint 1',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'New scope change',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '11030',
#         'id': '6731ad8904bc981d855712e2',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}}],
#       'jiraId': '10022',
#       'id': '66a7f83e2d4f9e11e43b8229',
#       'status': {'id': '66a7f5132d4f9e11e43b7bdf',
#        'title': 'In Progress',
#        'category': 'InProgress'}},
#      {'jiraIssueTypeId': '10000',
#       'storyPoints': 148.0,
#       'completion': 0.0,
#       'jiraKey': 'FEA-21',
#       'originItemId': '66a7f6df2d4f9e11e43b7de4',
#       'teamsAndSprints': [{'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#          'label': 'S3',
#          'title': 'Sprint 3',
#          'isIPSprint': False},
#         'team': {'color': '#e87e04',
#          'id': '5cec9edae21b841b49026d57',
#          'label': 'CRM',
#          'title': 'Team CRM'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#          'label': 'S1',
#          'title': 'Sprint 1',
#          'isIPSprint': False},
#         'team': {'color': '#6b47db',
#          'id': '5cec9ee5e21b841b49026d58',
#          'label': 'DWH',
#          'title': 'Team DWH'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#          'label': 'S2',
#          'title': 'Sprint 2',
#          'isIPSprint': False},
#         'team': {'color': '#6b47db',
#          'id': '5cec9ee5e21b841b49026d58',
#          'label': 'DWH',
#          'title': 'Team DWH'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#          'label': 'S3',
#          'title': 'Sprint 3',
#          'isIPSprint': False},
#         'team': {'color': '#6b47db',
#          'id': '5cec9ee5e21b841b49026d58',
#          'label': 'DWH',
#          'title': 'Team DWH'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#          'label': 'S1',
#          'title': 'Sprint 1',
#          'isIPSprint': False},
#         'team': {'color': '#336e7b',
#          'id': '5e77d14634704051634d110f',
#          'label': 'SKY',
#          'title': 'Team Sky'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#          'label': 'S3',
#          'title': 'Sprint 3',
#          'isIPSprint': False},
#         'team': {'color': '#336e7b',
#          'id': '5e77d14634704051634d110f',
#          'label': 'SKY',
#          'title': 'Team Sky'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#          'label': 'S2',
#          'title': 'Sprint 2',
#          'isIPSprint': False},
#         'team': {'color': '#e87e04',
#          'id': '5cec9edae21b841b49026d57',
#          'label': 'CRM',
#          'title': 'Team CRM'}}],
#       'title': 'CRM V 7.8 Roll-out to apps!',
#       'type': 'Feature',
#       'issueType': 'External Dependency',
#       'externalReferenceURL': 'javascript:void(0);',
#       'subItems': [{'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'VEN-3',
#         'originItemId': '66a7f6df2d4f9e11e43b7df2',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#            'label': 'S3',
#            'title': 'Sprint 3',
#            'isIPSprint': False},
#           'team': {'color': '#e87e04',
#            'id': '5cec9edae21b841b49026d57',
#            'label': 'CRM',
#            'title': 'Team CRM'}}],
#         'title': 'Integration work',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10239',
#         'id': '66a7f83e2d4f9e11e43b822c',
#         'status': {'id': '66a7f4dd2d4f9e11e43b7961',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'RED-2',
#         'originItemId': '66a7f6df2d4f9e11e43b7dfe',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'CRM system checks 4',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10047',
#         'id': '66a7f83e2d4f9e11e43b822e',
#         'status': {'id': '66a7f4dd2d4f9e11e43b797f',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 0.0,
#         'jiraKey': 'MARS-70',
#         'originItemId': '66a7f6df2d4f9e11e43b7e05',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'In Planning',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10495',
#         'id': '66a7f83e2d4f9e11e43b8230',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10004',
#         'storyPoints': 0.0,
#         'jiraKey': 'MARS-69',
#         'originItemId': '66a7f6df2d4f9e11e43b7e07',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#            'label': 'S3',
#            'title': 'Sprint 3',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'New Bug',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10489',
#         'id': '66a7f83e2d4f9e11e43b8231',
#         'status': {'id': '66a7f4dc2d4f9e11e43b792d',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'MARS-60',
#         'originItemId': '66a7f6df2d4f9e11e43b7e10',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'Sample story 2',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10471',
#         'id': '66a7f83e2d4f9e11e43b8232',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10004',
#         'jiraKey': 'MARS-58',
#         'originItemId': '66a7f6df2d4f9e11e43b7e12',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#            'label': 'S1',
#            'title': 'Sprint 1',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'Sample Bug',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10469',
#         'id': '66a7f83e2d4f9e11e43b8234',
#         'status': {'id': '66a7f4dc2d4f9e11e43b792b',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'MARS-34',
#         'originItemId': '66a7f6df2d4f9e11e43b7e1b',
#         'title': 'Backend scripts for s2',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10354',
#         'id': '66a7f83e2d4f9e11e43b8238',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'MARS-31',
#         'originItemId': '66a7f6df2d4f9e11e43b7e1f',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#            'label': 'S1',
#            'title': 'Sprint 1',
#            'isIPSprint': False},
#           'team': {'color': '#336e7b',
#            'id': '5e77d14634704051634d110f',
#            'label': 'SKY',
#            'title': 'Team Sky'}}],
#         'title': 'Roll out tests',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10350',
#         'id': '66a7f83e2d4f9e11e43b8239',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'MARS-27',
#         'originItemId': '66a7f6df2d4f9e11e43b7e23',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#            'label': 'S3',
#            'title': 'Sprint 3',
#            'isIPSprint': False},
#           'team': {'color': '#336e7b',
#            'id': '5e77d14634704051634d110f',
#            'label': 'SKY',
#            'title': 'Team Sky'}}],
#         'title': 'Test Story',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10334',
#         'id': '66a7f83e2d4f9e11e43b823a',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 13.0,
#         'jiraKey': 'MARS-25',
#         'originItemId': '66a7f6df2d4f9e11e43b7e26',
#         'title': 'Updates to DWH 2',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10325',
#         'id': '66a7f83e2d4f9e11e43b823b',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'MARS-24',
#         'originItemId': '66a7f6df2d4f9e11e43b7e28',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#e87e04',
#            'id': '5cec9edae21b841b49026d57',
#            'label': 'CRM',
#            'title': 'Team CRM'}}],
#         'title': 'Roll out backend scripts testing',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10243',
#         'id': '66a7f83e2d4f9e11e43b823c',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'MARS-23',
#         'originItemId': '66a7f6df2d4f9e11e43b7e29',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#            'label': 'S1',
#            'title': 'Sprint 1',
#            'isIPSprint': False},
#           'team': {'color': '#336e7b',
#            'id': '5e77d14634704051634d110f',
#            'label': 'SKY',
#            'title': 'Team Sky'}}],
#         'title': 'CRM v7.8 integration to emails',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10242',
#         'id': '66a7f83e2d4f9e11e43b823d',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'MARS-20',
#         'originItemId': '66a7f6df2d4f9e11e43b7e2d',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#            'label': 'S3',
#            'title': 'Sprint 3',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'Demo Story 5',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10070',
#         'id': '66a7f83e2d4f9e11e43b823e',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7927',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'MARS-3',
#         'originItemId': '66a7f6df2d4f9e11e43b7e2e',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#            'label': 'S1',
#            'title': 'Sprint 1',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'Retrieve products data from CRM',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10017',
#         'id': '66a7f83e2d4f9e11e43b823f',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'JUP-32',
#         'originItemId': '66a7f6df2d4f9e11e43b7e2f',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#            'label': 'S3',
#            'title': 'Sprint 3',
#            'isIPSprint': False},
#           'team': {'color': '#e87e04',
#            'id': '5cec9edae21b841b49026d57',
#            'label': 'CRM',
#            'title': 'Team CRM'}}],
#         'title': 'Work item new',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10491',
#         'id': '66a7f83e2d4f9e11e43b8240',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7943',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'JUP-18',
#         'originItemId': '66a7f6df2d4f9e11e43b7e3c',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#e87e04',
#            'id': '5cec9edae21b841b49026d57',
#            'label': 'CRM',
#            'title': 'Team CRM'}}],
#         'title': 'Roll out release testing ',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10353',
#         'id': '66a7f83e2d4f9e11e43b8241',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7943',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 13.0,
#         'jiraKey': 'GRN-3',
#         'originItemId': '66a7f6df2d4f9e11e43b7e43',
#         'title': 'V7.8 analysis for the changes',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10051',
#         'id': '66a7f83e2d4f9e11e43b8242',
#         'status': {'id': '66a7f5132d4f9e11e43b7bb4',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'GRN-1',
#         'originItemId': '66a7f6df2d4f9e11e43b7e46',
#         'title': 'CRM V 7.8 API Tests 2',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10031',
#         'id': '66a7f83e2d4f9e11e43b8243',
#         'status': {'id': '66a7f5132d4f9e11e43b7bb6',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 0.0,
#         'jiraKey': 'FEA-35',
#         'originItemId': '66a7f6df2d4f9e11e43b7e4a',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#            'label': 'S1',
#            'title': 'Sprint 1',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'Implement initial architecture for the component',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10372',
#         'id': '66a7f83e2d4f9e11e43b8244',
#         'status': {'id': '66a7f5132d4f9e11e43b7bd2',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'FEA-34',
#         'originItemId': '66a7f6df2d4f9e11e43b7e4b',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#            'label': 'S1',
#            'title': 'Sprint 1',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'Check test information',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10356',
#         'id': '66a7f83e2d4f9e11e43b8245',
#         'status': {'id': '66a7f5132d4f9e11e43b7bd2',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'FEA-29',
#         'originItemId': '66a7f6df2d4f9e11e43b7e4c',
#         'title': 'Automation scripts',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10321',
#         'id': '66a7f83e2d4f9e11e43b8246',
#         'status': {'id': '66a7f5132d4f9e11e43b7bd4',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 0.0,
#         'jiraKey': 'FEA-28',
#         'originItemId': '66a7f6df2d4f9e11e43b7e4d',
#         'title': 'System checks for V7.8',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10320',
#         'id': '66a7f83e2d4f9e11e43b8247',
#         'status': {'id': '66a7f5132d4f9e11e43b7bd6',
#          'title': 'To Do',
#          'category': 'ToDo'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 4.0,
#         'jiraKey': 'FEA-27',
#         'originItemId': '66a7f6df2d4f9e11e43b7e4e',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#            'label': 'S3',
#            'title': 'Sprint 3',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'Implementation of CRM checks',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10319',
#         'id': '66a7f83e2d4f9e11e43b8248',
#         'status': {'id': '66a7f5132d4f9e11e43b7bd2',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 3.0,
#         'jiraKey': 'JUP-173',
#         'title': 'londa',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10942',
#         'id': '671f74d7f1295970b0f23880',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7947',
#          'title': 'To Do',
#          'category': 'ToDo'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 4.0,
#         'jiraKey': 'JUP-174',
#         'title': 'GTO',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10943',
#         'id': '671f74e6af47151e0f4a8d01',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7945',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 3.0,
#         'jiraKey': 'JUP-176',
#         'title': 'BA',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10945',
#         'id': '671f74eff1295970b0f238a8',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7945',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 4.0,
#         'jiraKey': 'JUP-175',
#         'title': 'AM',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10944',
#         'id': '671f74f6af47151e0f4a8d27',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7945',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'jiraKey': 'FEA-54',
#         'title': 'New Work',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10998',
#         'id': '672f544e04bc981d8556de04',
#         'status': {'id': '66a7f5132d4f9e11e43b7bd6',
#          'title': 'To Do',
#          'category': 'ToDo'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'MARS-222',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'New Story',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '11165',
#         'id': '677d0508392d61251c559a28',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}}],
#       'jiraId': '10025',
#       'id': '66a7f83e2d4f9e11e43b8226',
#       'status': {'id': '66a7f5132d4f9e11e43b7bdf',
#        'title': 'In Progress',
#        'category': 'InProgress'}},
#      {'jiraIssueTypeId': '10000',
#       'storyPoints': 138.0,
#       'completion': 0.0,
#       'jiraKey': 'FEA-20',
#       'originItemId': '66a7f6df2d4f9e11e43b7de5',
#       'teamsAndSprints': [{'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#          'label': 'S2',
#          'title': 'Sprint 2',
#          'isIPSprint': False},
#         'team': {'color': '#c0392b',
#          'id': '5cec9ef2e21b841b49026d5b',
#          'label': 'TW',
#          'title': 'Team Whale'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#          'label': 'S1',
#          'title': 'Sprint 1',
#          'isIPSprint': False},
#         'team': {'color': '#c0392b',
#          'id': '5cec9ef2e21b841b49026d5b',
#          'label': 'TW',
#          'title': 'Team Whale'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#          'label': 'S1',
#          'title': 'Sprint 1',
#          'isIPSprint': False},
#         'team': {'color': '#e87e04',
#          'id': '5cec9edae21b841b49026d57',
#          'label': 'CRM',
#          'title': 'Team CRM'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#          'label': 'S1',
#          'title': 'Sprint 1',
#          'isIPSprint': False},
#         'team': {'color': '#336e7b',
#          'id': '5e77d14634704051634d110f',
#          'label': 'SKY',
#          'title': 'Team Sky'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#          'label': 'S1',
#          'title': 'Sprint 1',
#          'isIPSprint': False},
#         'team': {'color': '#6b47db',
#          'id': '5cec9ee5e21b841b49026d58',
#          'label': 'DWH',
#          'title': 'Team DWH'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#          'label': 'S2',
#          'title': 'Sprint 2',
#          'isIPSprint': False},
#         'team': {'color': '#e87e04',
#          'id': '5cec9edae21b841b49026d57',
#          'label': 'CRM',
#          'title': 'Team CRM'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#          'label': 'S2',
#          'title': 'Sprint 2',
#          'isIPSprint': False},
#         'team': {'color': '#6b47db',
#          'id': '5cec9ee5e21b841b49026d58',
#          'label': 'DWH',
#          'title': 'Team DWH'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#          'label': 'S3',
#          'title': 'Sprint 3',
#          'isIPSprint': False},
#         'team': {'color': '#6b47db',
#          'id': '5cec9ee5e21b841b49026d58',
#          'label': 'DWH',
#          'title': 'Team DWH'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d6',
#          'label': 'S4',
#          'title': 'Sprint 4',
#          'isIPSprint': False},
#         'team': {'color': '#6b47db',
#          'id': '5cec9ee5e21b841b49026d58',
#          'label': 'DWH',
#          'title': 'Team DWH'}}],
#       'title': 'CD: Customer Migration to new CRM',
#       'type': 'Feature',
#       'issueType': 'Feature',
#       'externalReferenceURL': 'javascript:void(0);',
#       'subItems': [{'jiraIssueTypeId': '10001',
#         'storyPoints': 7.0,
#         'jiraKey': 'RED-8',
#         'originItemId': '66a7f6df2d4f9e11e43b7df5',
#         'title': 'test3',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10346',
#         'id': '66a7f83e2d4f9e11e43b8254',
#         'status': {'id': '66a7f4dd2d4f9e11e43b797f',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'RED-7',
#         'originItemId': '66a7f6df2d4f9e11e43b7df7',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#c0392b',
#            'id': '5cec9ef2e21b841b49026d5b',
#            'label': 'TW',
#            'title': 'Team Whale'}}],
#         'title': 'test 2',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10345',
#         'id': '66a7f83e2d4f9e11e43b8255',
#         'status': {'id': '66a7f4dd2d4f9e11e43b797f',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'RED-6',
#         'originItemId': '66a7f6df2d4f9e11e43b7df8',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#c0392b',
#            'id': '5cec9ef2e21b841b49026d5b',
#            'label': 'TW',
#            'title': 'Team Whale'}}],
#         'title': 'test stort 5',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10344',
#         'id': '66a7f83e2d4f9e11e43b8256',
#         'status': {'id': '66a7f4dd2d4f9e11e43b797f',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'RED-5',
#         'originItemId': '66a7f6df2d4f9e11e43b7df9',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#            'label': 'S1',
#            'title': 'Sprint 1',
#            'isIPSprint': False},
#           'team': {'color': '#c0392b',
#            'id': '5cec9ef2e21b841b49026d5b',
#            'label': 'TW',
#            'title': 'Team Whale'}}],
#         'title': 'test story open 2',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10343',
#         'id': '66a7f83e2d4f9e11e43b8257',
#         'status': {'id': '66a7f4dd2d4f9e11e43b797f',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'RED-4',
#         'originItemId': '66a7f6df2d4f9e11e43b7dfb',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#c0392b',
#            'id': '5cec9ef2e21b841b49026d5b',
#            'label': 'TW',
#            'title': 'Team Whale'}}],
#         'title': 'Test story 1',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10342',
#         'id': '66a7f83e2d4f9e11e43b8258',
#         'status': {'id': '66a7f4dd2d4f9e11e43b797f',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'RED-3',
#         'originItemId': '66a7f6df2d4f9e11e43b7dfc',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#            'label': 'S1',
#            'title': 'Sprint 1',
#            'isIPSprint': False},
#           'team': {'color': '#e87e04',
#            'id': '5cec9edae21b841b49026d57',
#            'label': 'CRM',
#            'title': 'Team CRM'}}],
#         'title': 'Migration scripts design.',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10048',
#         'id': '66a7f83e2d4f9e11e43b8259',
#         'status': {'id': '66a7f4dd2d4f9e11e43b7981',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 3.0,
#         'jiraKey': 'MARS-65',
#         'originItemId': '66a7f6df2d4f9e11e43b7e0b',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#            'label': 'S1',
#            'title': 'Sprint 1',
#            'isIPSprint': False},
#           'team': {'color': '#336e7b',
#            'id': '5e77d14634704051634d110f',
#            'label': 'SKY',
#            'title': 'Team Sky'}}],
#         'title': 'Test story',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10482',
#         'id': '66a7f83e2d4f9e11e43b825f',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'MARS-64',
#         'originItemId': '66a7f6df2d4f9e11e43b7e0d',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d6',
#            'label': 'S4',
#            'title': 'Sprint 4',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'Search Updates',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10479',
#         'id': '66a7f83e2d4f9e11e43b8260',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7929',
#          'title': 'To Do',
#          'category': 'ToDo'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'MARS-61',
#         'originItemId': '66a7f6df2d4f9e11e43b7e0f',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'DRM related work',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10472',
#         'id': '66a7f83e2d4f9e11e43b8262',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10004',
#         'jiraKey': 'JUP-31',
#         'originItemId': '66a7f6df2d4f9e11e43b7e30',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#e87e04',
#            'id': '5cec9edae21b841b49026d57',
#            'label': 'CRM',
#            'title': 'Team CRM'}}],
#         'title': 'Sync not updating',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10485',
#         'id': '66a7f83e2d4f9e11e43b827c',
#         'status': {'id': '66a7f4dc2d4f9e11e43b794b',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'JUP-30',
#         'originItemId': '66a7f6df2d4f9e11e43b7e32',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#e87e04',
#            'id': '5cec9edae21b841b49026d57',
#            'label': 'CRM',
#            'title': 'Team CRM'}}],
#         'title': 'Deployment support',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10484',
#         'id': '66a7f83e2d4f9e11e43b827d',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7945',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'JUP-29',
#         'originItemId': '66a7f6df2d4f9e11e43b7e33',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#e87e04',
#            'id': '5cec9edae21b841b49026d57',
#            'label': 'CRM',
#            'title': 'Team CRM'}}],
#         'title': 'Customer engagement logging',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10481',
#         'id': '66a7f83e2d4f9e11e43b827e',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7943',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'JUP-26',
#         'originItemId': '66a7f6df2d4f9e11e43b7e35',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#e87e04',
#            'id': '5cec9edae21b841b49026d57',
#            'label': 'CRM',
#            'title': 'Team CRM'}}],
#         'title': 'CRM Migration tests',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10458',
#         'id': '66a7f83e2d4f9e11e43b8280',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7943',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'JUP-23',
#         'originItemId': '66a7f6df2d4f9e11e43b7e3a',
#         'title': 'CRM Management',
#         'type': 'UserStory',
#         'issueType': 'Story',
# ...
#         'title': 'Before closing 1',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10339',
#         'id': '66a7f83e2d4f9e11e43b829b',
#         'status': {'id': '66a7f4de2d4f9e11e43b79a9',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 3.0,
#         'jiraKey': 'JUP-153',
#         'title': 'killer',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10906',
#         'id': '671f7163af47151e0f4a8755',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7943',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 3.0,
#         'jiraKey': 'JUP-154',
#         'title': 'Karoki',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10907',
#         'id': '671f716f62738246350a6205',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7945',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 4.0,
#         'jiraKey': 'JUP-155',
#         'title': 'dribbling',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10908',
#         'id': '671f7176e5b4574362e17881',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7945',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 4.0,
#         'jiraKey': 'JUP-156',
#         'title': 'koko',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10909',
#         'id': '671f718aaf47151e0f4a8794',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7945',
#          'title': 'In Progress',
#          'category': 'InProgress'}}],
#       'jiraId': '10024',
#       'id': '66a7f83e2d4f9e11e43b8227',
#       'status': {'id': '66a7f5132d4f9e11e43b7bdf',
#        'title': 'In Progress',
#        'category': 'InProgress'}},
#      {'jiraIssueTypeId': '10000',
#       'storyPoints': 64.0,
#       'completion': 0.0,
#       'jiraKey': 'FEA-18',
#       'originItemId': '66a7f6df2d4f9e11e43b7de7',
#       'teamsAndSprints': [{'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#          'label': 'S3',
#          'title': 'Sprint 3',
#          'isIPSprint': False},
#         'team': {'color': '#336e7b',
#          'id': '5e77d14634704051634d110f',
#          'label': 'SKY',
#          'title': 'Team Sky'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#          'label': 'S2',
#          'title': 'Sprint 2',
#          'isIPSprint': False},
#         'team': {'color': '#6b47db',
#          'id': '5cec9ee5e21b841b49026d58',
#          'label': 'DWH',
#          'title': 'Team DWH'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#          'label': 'S1',
#          'title': 'Sprint 1',
#          'isIPSprint': False},
#         'team': {'color': '#e87e04',
#          'id': '5cec9edae21b841b49026d57',
#          'label': 'CRM',
#          'title': 'Team CRM'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#          'label': 'S1',
#          'title': 'Sprint 1',
#          'isIPSprint': False},
#         'team': {'color': '#6b47db',
#          'id': '5cec9ee5e21b841b49026d58',
#          'label': 'DWH',
#          'title': 'Team DWH'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#          'label': 'S3',
#          'title': 'Sprint 3',
#          'isIPSprint': False},
#         'team': {'color': '#6b47db',
#          'id': '5cec9ee5e21b841b49026d58',
#          'label': 'DWH',
#          'title': 'Team DWH'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d6',
#          'label': 'S4',
#          'title': 'Sprint 4',
#          'isIPSprint': False},
#         'team': {'color': '#6b47db',
#          'id': '5cec9ee5e21b841b49026d58',
#          'label': 'DWH',
#          'title': 'Team DWH'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d6',
#          'label': 'S4',
#          'title': 'Sprint 4',
#          'isIPSprint': False},
#         'team': {'color': '#e87e04',
#          'id': '5cec9edae21b841b49026d57',
#          'label': 'CRM',
#          'title': 'Team CRM'}},
#        {'sequence': 72544349219.0,
#         'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#          'label': 'S2',
#          'title': 'Sprint 2',
#          'isIPSprint': False},
#         'team': {'color': '#336e7b',
#          'id': '5e77d14634704051634d110f',
#          'label': 'SKY',
#          'title': 'Team Sky'}}],
#       'title': 'Nightly Sync from New to older DWH for Reporting',
#       'type': 'Feature',
#       'issueType': 'Feature',
#       'externalReferenceURL': 'javascript:void(0);',
#       'subItems': [{'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'VEN-5',
#         'originItemId': '66a7f6df2d4f9e11e43b7dee',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#336e7b',
#            'id': '5e77d14634704051634d110f',
#            'label': 'SKY',
#            'title': 'Team Sky'}}],
#         'title': 'Multiple adds scenario',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10241',
#         'id': '66a7f83e2d4f9e11e43b8252',
#         'status': {'id': '66a7f4dd2d4f9e11e43b7965',
#          'title': 'To Do',
#          'category': 'ToDo'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'VEN-4',
#         'originItemId': '66a7f6df2d4f9e11e43b7df0',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#            'label': 'S3',
#            'title': 'Sprint 3',
#            'isIPSprint': False},
#           'team': {'color': '#336e7b',
#            'id': '5e77d14634704051634d110f',
#            'label': 'SKY',
#            'title': 'Team Sky'}}],
#         'title': 'DWH reporting updates for CRM 1',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10240',
#         'id': '66a7f83e2d4f9e11e43b8253',
#         'status': {'id': '66a7f4dd2d4f9e11e43b7963',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10004',
#         'storyPoints': 0.0,
#         'jiraKey': 'MARS-71',
#         'originItemId': '66a7f6df2d4f9e11e43b7e03',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'CLONE - DWH checks missing',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10496',
#         'id': '66a7f83e2d4f9e11e43b825b',
#         'status': {'id': '66a7f4dc2d4f9e11e43b792b',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10004',
#         'jiraKey': 'MARS-68',
#         'originItemId': '66a7f6df2d4f9e11e43b7e08',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#            'label': 'S3',
#            'title': 'Sprint 3',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'DWH checks missing',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10488',
#         'id': '66a7f83e2d4f9e11e43b825c',
#         'status': {'id': '66a7f4dc2d4f9e11e43b792b',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10004',
#         'storyPoints': 0.0,
#         'jiraKey': 'MARS-67',
#         'originItemId': '66a7f6df2d4f9e11e43b7e09',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'CSS issue',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10487',
#         'id': '66a7f83e2d4f9e11e43b825d',
#         'status': {'id': '66a7f4dc2d4f9e11e43b792b',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10004',
#         'jiraKey': 'MARS-66',
#         'originItemId': '66a7f6df2d4f9e11e43b7e0a',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d4',
#            'label': 'S2',
#            'title': 'Sprint 2',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'Another',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10486',
#         'id': '66a7f83e2d4f9e11e43b825e',
#         'status': {'id': '66a7f4dc2d4f9e11e43b792b',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'MARS-44',
#         'originItemId': '66a7f6df2d4f9e11e43b7e16',
#         'title': 'Test 2',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10384',
#         'id': '66a7f83e2d4f9e11e43b8264',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7927',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 0.0,
#         'jiraKey': 'MARS-43',
#         'originItemId': '66a7f6df2d4f9e11e43b7e17',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d6',
#            'label': 'S4',
#            'title': 'Sprint 4',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'My WB test',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10381',
#         'id': '66a7f83e2d4f9e11e43b8265',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'MARS-39',
#         'originItemId': '66a7f6df2d4f9e11e43b7e1a',
#         'title': 'New Story for SP2',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10373',
#         'id': '66a7f83e2d4f9e11e43b8268',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 0.0,
#         'jiraKey': 'JUP-24',
#         'originItemId': '66a7f6df2d4f9e11e43b7e38',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#            'label': 'S1',
#            'title': 'Sprint 1',
#            'isIPSprint': False},
#           'team': {'color': '#e87e04',
#            'id': '5cec9edae21b841b49026d57',
#            'label': 'CRM',
#            'title': 'Team CRM'}}],
#         'title': 'Synchronization Phase 1',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10386',
#         'id': '66a7f83e2d4f9e11e43b8282',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7945',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 5.0,
#         'jiraKey': 'JUP-19',
#         'originItemId': '66a7f6df2d4f9e11e43b7e3b',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d5',
#            'label': 'S3',
#            'title': 'Sprint 3',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'System checks',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10355',
#         'id': '66a7f83e2d4f9e11e43b8286',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7943',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 13.0,
#         'jiraKey': 'JUP-15',
#         'originItemId': '66a7f6df2d4f9e11e43b7e3d',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d6',
#            'label': 'S4',
#            'title': 'Sprint 4',
#            'isIPSprint': False},
#           'team': {'color': '#e87e04',
#            'id': '5cec9edae21b841b49026d57',
#            'label': 'CRM',
#            'title': 'Team CRM'}}],
#         'title': 'Story 5',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10333',
#         'id': '66a7f83e2d4f9e11e43b8287',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7943',
#          'title': 'Done',
#          'category': 'Done'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 4.0,
#         'jiraKey': 'MARS-199',
#         'title': 'gang',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10910',
#         'id': '671f7190f1295970b0f23503',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7927',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 4.0,
#         'jiraKey': 'MARS-200',
#         'title': 'bala',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10911',
#         'id': '671f71a0af47151e0f4a87d4',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7927',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 4.0,
#         'jiraKey': 'MARS-201',
#         'title': 'gaadi',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10912',
#         'id': '671f71b1af47151e0f4a87ff',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7927',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 3.0,
#         'jiraKey': 'MARS-202',
#         'title': 'pati',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '10913',
#         'id': '671f71b2dec74417c3c18d3f',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7927',
#          'title': 'In Progress',
#          'category': 'InProgress'}},
#        {'jiraIssueTypeId': '10001',
#         'storyPoints': 8.0,
#         'jiraKey': 'MARS-219',
#         'teamsAndSprints': [{'sequence': 72544349794.0,
#           'sprint': {'id': '66a7f83d2d4f9e11e43b81d3',
#            'label': 'S1',
#            'title': 'Sprint 1',
#            'isIPSprint': False},
#           'team': {'color': '#6b47db',
#            'id': '5cec9ee5e21b841b49026d58',
#            'label': 'DWH',
#            'title': 'Team DWH'}}],
#         'title': 'New scope change',
#         'type': 'UserStory',
#         'issueType': 'Story',
#         'jiraId': '11030',
#         'id': '6731ad8904bc981d855712e2',
#         'status': {'id': '66a7f4dc2d4f9e11e43b7925',
#          'title': 'Done',
#          'category': 'Done'}}],
#       'jiraId': '10022',
#       'id': '66a7f83e2d4f9e11e43b8229',
#       'status': {'id': '66a7f5132d4f9e11e43b7bdf',
#        'title': 'In Progress',
#        'category': 'InProgress'}}],
#     'id': 'OBJ-57',
#     'status': {'id': '64bd1e35e8721807d84464b6',
#      'title': 'Planned',
#      'category': 'ToDo'}}],
#   'id': '66c74f9144fa0a12c5466b63',
#   'title': 'Business Goals for Q3',
#   'type': 'CustomGroup',
#   'status': {'id': '667402bb98032b3c3c63fbe6',
#    'title': 'Not Started',
#    'category': 'ToDo'}}]

# %% [markdown]
# ## Program Board Items API calls

# %% [markdown]
# ### 1. Retrieve List of Program Board Items

# %%
# Example Request 1: User want to fetch default fields for a board

import json
import requests

url = 'https://rest.kendis.io/api/example/items'
# Define the body as a Python dictionary
payload = {
    "boardId":"6756b1b0216f0c3a2bb8ae6e"
}

# Convert the dictionary to a raw JSON string
raw_json_body = json.dumps(payload)
# Send the GET request with Basic Auth
response = requests.post(url, data=raw_json_body, auth=(username, password), headers={"Content-Type": "application/json"})
# Check the response
if response.status_code == 200:
    # Successfully retrieved data
    items_data = response.json()  # Parse JSON response
    print("Data retrieved successfully:")
    print(items_data)
else:
    # Handle error
    print(f"Failed to retrieve data. HTTP Status Code: {response.status_code}")
    print("Response content:", response.text)
# Out:
# Data retrieved successfully:
# {'data': [{'summary': 'Frontend for Web2', 'azureId': '2', 'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\Iteration-1', 'kendisId': '6756b1da216f0c3a2bb8b034', 'parentId': '336', 'parentDescription': 'CRM and Billing Systems', 'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'}, 'team': {'id': '5cec9edae21b841b49026d57'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'}, 'team': {'id': '5cec9edae21b841b49026d57'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'}, 'team': {'id': '5cec9ef2e21b841b49026d5b'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'}, 'team': {'id': '60edb734e48f063fb84f4094'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'}, 'team': {'id': '60edb734e48f063fb84f4094'}}]}, {'summary': 'CRM System Updates for v1.7', 'azureId': '5', 'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\TW-Sprint5.3', 'kendisId': '6756b1da216f0c3a2bb8b035', 'parentId': '321', 'parentDescription': 'Shopping Cart System', 'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'}, 'team': {'id': '5cec9ee5e21b841b49026d58'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'}, 'team': {'id': '5cec9edae21b841b49026d57'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'}, 'team': {'id': '5cec9ef2e21b841b49026d5b'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'}, 'team': {'id': '5cec9ee5e21b841b49026d58'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'}, 'team': {'id': '5cec9edae21b841b49026d57'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'}, 'team': {'id': '60edb734e48f063fb84f4094'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'}, 'team': {'id': '60edb734e48f063fb84f4094'}}]}, {'summary': 'DWH Nightly Sync!', 'azureId': '6', 'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\SKY-Sprint5.1', 'kendisId': '6756b1da216f0c3a2bb8b036', 'parentId': '336', 'parentDescription': 'CRM and Billing Systems', 'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'}, 'team': {'id': '5cec9ee5e21b841b49026d58'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'}, 'team': {'id': '5cec9ef2e21b841b49026d5b'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'}, 'team': {'id': '5cec9edae21b841b49026d57'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'}, 'team': {'id': '5cec9edae21b841b49026d57'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'}, 'team': {'id': '5cec9edae21b841b49026d57'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'}, 'team': {'id': '64748ba7200f9f7d32f94741'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'}, 'team': {'id': '60edb734e48f063fb84f4094'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'}, 'team': {'id': '60edb734e48f063fb84f4094'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'}, 'team': {'id': '60edb734e48f063fb84f4094'}}]}, {'summary': 'Shopping Cart Design 80', 'azureId': '7', 'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\TW-Sprint5.1', 'kendisId': '6756b1db216f0c3a2bb8b037', 'parentId': '321', 'parentDescription': 'Shopping Cart System', 'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'}, 'team': {'id': '5cec9edae21b841b49026d57'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'}, 'team': {'id': '5cec9ef2e21b841b49026d5b'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'}, 'team': {'id': '60edb734e48f063fb84f4094'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'}, 'team': {'id': '60edb734e48f063fb84f4094'}}]}, {'summary': 'Checkout Experience with payment', 'azureId': '8', 'itemType': 'Feature', 'iterationPath': 'ZAP - Agile', 'kendisId': '6756b1db216f0c3a2bb8b038', 'parentId': '321', 'parentDescription': 'Shopping Cart System', 'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'}, 'team': {'id': '5cec9ef2e21b841b49026d5b'}}, {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'}, 'team': {'id': '5cec9ef2e21b841b49026d5b'}}]}, {'summary': 'CRM Sync for B2B Billing data systems from companies', 'azureId': '9', 'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\Iteration-1', 'kendisId': '6756b1db216f0c3a2bb8b039', 'parentId': '321', 'parentDescription': 'Shopping Cart System', 'teamsA ...

# %%
items_data['data']
# Out:
# [{'summary': 'Frontend for Web2',
#   'azureId': '2',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\Iteration-1',
#   'kendisId': '6756b1da216f0c3a2bb8b034',
#   'parentId': '336',
#   'parentDescription': 'CRM and Billing Systems',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '60edb734e48f063fb84f4094'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '60edb734e48f063fb84f4094'}}]},
#  {'summary': 'CRM System Updates for v1.7',
#   'azureId': '5',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\TW-Sprint5.3',
#   'kendisId': '6756b1da216f0c3a2bb8b035',
#   'parentId': '321',
#   'parentDescription': 'Shopping Cart System',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '5cec9ee5e21b841b49026d58'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '5cec9ee5e21b841b49026d58'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '60edb734e48f063fb84f4094'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '60edb734e48f063fb84f4094'}}]},
#  {'summary': 'DWH Nightly Sync!',
#   'azureId': '6',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\SKY-Sprint5.1',
#   'kendisId': '6756b1da216f0c3a2bb8b036',
#   'parentId': '336',
#   'parentDescription': 'CRM and Billing Systems',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '5cec9ee5e21b841b49026d58'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '64748ba7200f9f7d32f94741'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '60edb734e48f063fb84f4094'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '60edb734e48f063fb84f4094'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '60edb734e48f063fb84f4094'}}]},
#  {'summary': 'Shopping Cart Design 80',
#   'azureId': '7',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\TW-Sprint5.1',
#   'kendisId': '6756b1db216f0c3a2bb8b037',
#   'parentId': '321',
#   'parentDescription': 'Shopping Cart System',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '60edb734e48f063fb84f4094'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'},
#     'team': {'id': '60edb734e48f063fb84f4094'}}]},
#  {'summary': 'Checkout Experience with payment',
#   'azureId': '8',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'kendisId': '6756b1db216f0c3a2bb8b038',
#   'parentId': '321',
#   'parentDescription': 'Shopping Cart System',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#  {'summary': 'CRM Sync for B2B Billing data systems from companies',
#   'azureId': '9',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\Iteration-1',
#   'kendisId': '6756b1db216f0c3a2bb8b039',
#   'parentId': '321',
#   'parentDescription': 'Shopping Cart System',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'},
#     'team': {'id': '60edb734e48f063fb84f4094'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '60edb734e48f063fb84f4094'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '60edb734e48f063fb84f4094'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '60edb734e48f063fb84f4094'}}]},
#  {'summary': 'Search for products listing 5',
#   'azureId': '10',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\TW-Sprint5.3',
#   'kendisId': '6756b1db216f0c3a2bb8b03a',
#   'parentId': '321',
#   'parentDescription': 'Shopping Cart System',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '60edb734e48f063fb84f4094'}}]},
#  {'summary': 'Mobile version of the website',
#   'azureId': '55',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\TW-Sprint5.3',
#   'kendisId': '6756b1db216f0c3a2bb8b03b',
#   'parentId': '337',
#   'parentDescription': 'Mobile Systems Integration',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#  {'summary': 'Vendor Delivery Delay could impact the Release.',
#   'azureId': '71',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'kendisId': '6756b1db216f0c3a2bb8b03c'},
#  {'summary': 'Build backend for bookstore search',
#   'azureId': '96',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\A-SKY-Sprint5.4',
#   'kendisId': '6756b1db216f0c3a2bb8b03d',
#   'parentId': '336',
#   'parentDescription': 'CRM and Billing Systems',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '60edb734e48f063fb84f4094'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '60edb734e48f063fb84f4094'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '60edb734e48f063fb84f4094'}}]},
#  {'summary': 'Enable the Mobile Ticket app',
#   'azureId': '100',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\Q22024',
#   'kendisId': '6756b1db216f0c3a2bb8b03e',
#   'parentId': '337',
#   'parentDescription': 'Mobile Systems Integration',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#  {'summary': 'Checkout Experience',
#   'azureId': '101',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'kendisId': '6756b1db216f0c3a2bb8b03f',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '5cec9ee5e21b841b49026d58'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '60edb734e48f063fb84f4094'}}]},
#  {'summary': 'Demo Feature for Program Board',
#   'azureId': '108',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\SKY-Sprint5.2',
#   'kendisId': '6756b1db216f0c3a2bb8b040',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#  {'summary': 'Shopping cart checklist',
#   'azureId': '113',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\Iteration-1',
#   'kendisId': '6756b1db216f0c3a2bb8b041',
#   'parentId': '321',
#   'parentDescription': 'Shopping Cart System',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '60edb734e48f063fb84f4094'}}]},
#  {'summary': 'Vendor Management',
#   'azureId': '114',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\Iteration-1',
#   'kendisId': '6756b1db216f0c3a2bb8b042',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#  {'summary': 'Demo Feature',
#   'azureId': '134',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'kendisId': '6756b1db216f0c3a2bb8b043'},
#  {'summary': 'backend scripts',
#   'azureId': '152',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'kendisId': '6756b1db216f0c3a2bb8b044'},
#  {'summary': 'Smart search integration with CRM',
#   'azureId': '159',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\TGR-Sprint5.3',
#   'kendisId': '6756b1db216f0c3a2bb8b045'},
#  {'summary': 'Search Filter',
#   'azureId': '171',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'kendisId': '6756b1db216f0c3a2bb8b046',
#   'parentId': '337',
#   'parentDescription': 'Mobile Systems Integration',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '5cec9ee5e21b841b49026d58'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#  {'summary': 'CRM sys updates',
#   'azureId': '175',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\TGR-Sprint5.3',
#   'kendisId': '6756b1db216f0c3a2bb8b047'},
#  {'summary': 'Auto update DWH with nightly sync',
#   'azureId': '197',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'kendisId': '6756b1db216f0c3a2bb8b048',
#   'parentId': '198',
#   'parentDescription': 'Team changes '},
#  {'summary': 'Demo Feature - From ADO to Kendis',
#   'azureId': '211',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\Iteration-1',
#   'kendisId': '6756b1db216f0c3a2bb8b049',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '5cec9ee5e21b841b49026d58'}}]},
#  {'summary': 'New assigned to team',
#   'azureId': '212',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\Iteration 2',
#   'kendisId': '6756b1db216f0c3a2bb8b04a'},
#  {'summary': 'Demo Feature added',
#   'azureId': '239',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'kendisId': '6756b1db216f0c3a2bb8b04b',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '5cec9ee5e21b841b49026d58'}}]},
#  {'summary': 'DWH Sync for nightly updates 2.7',
#   'azureId': '289',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\TGR-Sprint5.3',
#   'kendisId': '6756b1db216f0c3a2bb8b04c',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '5cec9ee5e21b841b49026d58'}}]},
#  {'summary': 'Improvements in the sync process',
#   'azureId': '290',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\TGR-Sprint5.3',
#   'kendisId': '6756b1db216f0c3a2bb8b04d',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#  {'summary': 'CMS Updates',
#   'azureId': '299',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'kendisId': '6756b1db216f0c3a2bb8b04e',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#  {'summary': 'Add search results to shopping cart2',
#   'azureId': '326',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\Q22024',
#   'kendisId': '6756b1db216f0c3a2bb8b04f',
#   'parentId': '1',
#   'parentDescription': 'Demo Epic A',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '60edb734e48f063fb84f4094'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#     'team': {'id': '60edb734e48f063fb84f4094'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#     'team': {'id': '60edb734e48f063fb84f4094'}}]},
#  {'summary': 'Third party vendor delivery',
#   'azureId': '366',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\For Universe1',
#   'kendisId': '6756b1db216f0c3a2bb8b050'},
#  {'summary': 'New Feature x',
#   'azureId': '367',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\For Universe1',
#   'kendisId': '6756b1db216f0c3a2bb8b051',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '5cec9edae21b841b49026d57'}},
#    {'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#     'team': {'id': '60edb734e48f063fb84f4094'}}]},
#  {'summary': 'Content Suggestions',
#   'azureId': '383',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'kendisId': '6756b1db216f0c3a2bb8b052',
#   'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'},
#     'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#  {'summary': 'Feature under Epic',
#   'azureId': '394',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\Iteration-1',
#   'kendisId': '6756b1db216f0c3a2bb8b053',
#   'parentId': '1',
#   'parentDescription': 'Demo Epic A'},
#  {'summary': 'Feature for Team Sea',
#   'azureId': '395',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\Q22024',
#   'kendisId': '6756b1db216f0c3a2bb8b054',
#   'parentId': '1',
#   'parentDescription': 'Demo Epic A'},
#  {'summary': 'Demo1',
#   'azureId': '400',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\TGR-Sprint5.2',
#   'kendisId': '6756b1db216f0c3a2bb8b055'},
#  {'summary': 'Feature 1',
#   'azureId': '415',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'kendisId': '6756b1db216f0c3a2bb8b056'},
#  {'summary': 'Bugs',
#   'azureId': '416',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\Univ2-2',
#   'kendisId': '6756b1db216f0c3a2bb8b057',
#   'parentId': '365',
#   'parentDescription': 'Top epic'},
#  {'summary': 'Create New Feature',
#   'azureId': '1075',
#   'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'kendisId': '6780dfcd362af5328dc15f01'}]

# %%
# Example Request 2: If users want 20 features and their children on page 1.

import json
import requests

url = 'https://rest.kendis.io/api/example/items'
# Define the body as a Python dictionary
payload = {
    "boardId":"6756b1b0216f0c3a2bb8ae6e",
   "pageStart" : 1,
   "pageSize" : 20,
   "fields":["children"]
}

# Convert the dictionary to a raw JSON string
raw_json_body = json.dumps(payload)
# Send the GET request with Basic Auth
response = requests.post(url, data=raw_json_body, auth=(username, password), headers={"Content-Type": "application/json"})
# Check the response
if response.status_code == 200:
    # Successfully retrieved data
    items_data = response.json()  # Parse JSON response
    print("Data retrieved successfully:")
    print(items_data)
else:
    # Handle error
    print(f"Failed to retrieve data. HTTP Status Code: {response.status_code}")
    print("Response content:", response.text)
# Out:
# Data retrieved successfully:
# {'data': [{'kendisId': '6756b1da216f0c3a2bb8b035', 'children': [{'summary': 'CRM system checks on daily basis updates to new 23', 'estimates': 8.0, 'azureId': '11', 'status': {'id': '6756b1b1216f0c3a2bb8aeaa'}, 'kendisId': '6756b1dc216f0c3a2bb8b078', 'parentId': '6756b1da216f0c3a2bb8b035', 'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'}, 'team': {'id': '5cec9ee5e21b841b49026d58'}}]}, {'summary': 'New Story from ADO', 'estimates': 5.0, 'azureId': '401', 'status': {'id': '6756b1b1216f0c3a2bb8aea9'}, 'kendisId': '6756b1dc216f0c3a2bb8b08c', 'parentId': '6756b1da216f0c3a2bb8b035'}, {'summary': 'CRM Migration scripts', 'estimates': 8.0, 'azureId': '411', 'status': {'id': '6756b1b1216f0c3a2bb8aea9'}, 'kendisId': '6756b1dc216f0c3a2bb8b09e', 'parentId': '6756b1da216f0c3a2bb8b035', 'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'}, 'team': {'id': '5cec9ee5e21b841b49026d58'}}]}, {'summary': 'CRM System', 'estimates': 5.0, 'azureId': '144', 'status': {'id': '6756b1b1216f0c3a2bb8aeac'}, 'kendisId': '6756b1dc216f0c3a2bb8b0ab', 'parentId': '6756b1da216f0c3a2bb8b035'}, {'summary': 'CRM - checks', 'estimates': 0.0, 'azureId': '420', 'status': {'id': '6756b1b1216f0c3a2bb8aea9'}, 'kendisId': '6756b1dc216f0c3a2bb8b0ad', 'parentId': '6756b1da216f0c3a2bb8b035', 'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'}, 'team': {'id': '60edb734e48f063fb84f4094'}}]}, {'summary': 'New Story for CRM in Team whale', 'estimates': 5.0, 'azureId': '302', 'status': {'id': '6756b1b1216f0c3a2bb8aea9'}, 'kendisId': '6756b1dc216f0c3a2bb8b0b3', 'parentId': '6756b1da216f0c3a2bb8b035', 'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'}, 'team': {'id': '5cec9ef2e21b841b49026d5b'}}]}, {'summary': 'Back end work for CRM scripts', 'estimates': 8.0, 'azureId': '49', 'status': {'id': '6756b1b1216f0c3a2bb8aeab'}, 'kendisId': '6756b1dc216f0c3a2bb8b0ba', 'parentId': '6756b1da216f0c3a2bb8b035', 'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'}, 'team': {'id': '60edb734e48f063fb84f4094'}}]}, {'summary': 'Dependent story', 'estimates': 13.0, 'azureId': '162', 'status': {'id': '6756b1b1216f0c3a2bb8aeab'}, 'kendisId': '6756b1dc216f0c3a2bb8b0cb', 'parentId': '6756b1da216f0c3a2bb8b035', 'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'}, 'team': {'id': '5cec9ee5e21b841b49026d58'}}]}, {'summary': 'story', 'estimates': 3.0, 'azureId': '63', 'status': {'id': '6756b1b1216f0c3a2bb8aeac'}, 'kendisId': '6756b1dc216f0c3a2bb8b0d6', 'parentId': '6756b1da216f0c3a2bb8b035'}, {'summary': 'CRM to DWH scripts-', 'estimates': 8.0, 'azureId': '69', 'status': {'id': '6756b1b1216f0c3a2bb8aeac'}, 'kendisId': '6756b1dc216f0c3a2bb8b0d7', 'parentId': '6756b1da216f0c3a2bb8b035', 'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'}, 'team': {'id': '60edb734e48f063fb84f4094'}}]}, {'summary': 'New Team story', 'estimates': 0.0, 'azureId': '176', 'status': {'id': '6756b1b1216f0c3a2bb8aeac'}, 'kendisId': '6756b1dc216f0c3a2bb8b0e3', 'parentId': '6756b1da216f0c3a2bb8b035'}, {'summary': 'NGNIX Gateway', 'estimates': 3.0, 'azureId': '179', 'status': {'id': '6756b1b1216f0c3a2bb8aea9'}, 'kendisId': '6756b1dc216f0c3a2bb8b0eb', 'parentId': '6756b1da216f0c3a2bb8b035'}]}, {'kendisId': '6756b1da216f0c3a2bb8b036', 'children': [{'summary': 'CRM Backend script updates', 'estimates': 8.0, 'azureId': '194', 'status': {'id': '6756b1b1216f0c3a2bb8aea9'}, 'kendisId': '6756b1db216f0c3a2bb8b05f', 'parentId': '6756b1da216f0c3a2bb8b036', 'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'}, 'team': {'id': '5cec9ee5e21b841b49026d58'}}]}, {'summary': 'Demo Story', 'estimates': 0.0, 'azureId': '92', 'status': {'id': '6756b1b1216f0c3a2bb8aeac'}, 'kendisId': '6756b1dc216f0c3a2bb8b073', 'parentId': '6756b1da216f0c3a2bb8b036', 'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'}, 'team': {'id': '5cec9ef2e21b841b49026d5b'}}]}, {'summary': 'Nightly sync scripts initial design', 'estimates': 0.0, 'azureId': '12', 's ...

# %%
items_data['data']
# Out:
# [{'kendisId': '6756b1da216f0c3a2bb8b035',
#   'children': [{'summary': 'CRM system checks on daily basis updates to new 23',
#     'estimates': 8.0,
#     'azureId': '11',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeaa'},
#     'kendisId': '6756b1dc216f0c3a2bb8b078',
#     'parentId': '6756b1da216f0c3a2bb8b035',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '5cec9ee5e21b841b49026d58'}}]},
#    {'summary': 'New Story from ADO',
#     'estimates': 5.0,
#     'azureId': '401',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b08c',
#     'parentId': '6756b1da216f0c3a2bb8b035'},
#    {'summary': 'CRM Migration scripts',
#     'estimates': 8.0,
#     'azureId': '411',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b09e',
#     'parentId': '6756b1da216f0c3a2bb8b035',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '5cec9ee5e21b841b49026d58'}}]},
#    {'summary': 'CRM System',
#     'estimates': 5.0,
#     'azureId': '144',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0ab',
#     'parentId': '6756b1da216f0c3a2bb8b035'},
#    {'summary': 'CRM - checks',
#     'estimates': 0.0,
#     'azureId': '420',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0ad',
#     'parentId': '6756b1da216f0c3a2bb8b035',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'New Story for CRM in Team whale',
#     'estimates': 5.0,
#     'azureId': '302',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0b3',
#     'parentId': '6756b1da216f0c3a2bb8b035',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#    {'summary': 'Back end work for CRM scripts',
#     'estimates': 8.0,
#     'azureId': '49',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeab'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0ba',
#     'parentId': '6756b1da216f0c3a2bb8b035',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'Dependent story',
#     'estimates': 13.0,
#     'azureId': '162',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeab'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0cb',
#     'parentId': '6756b1da216f0c3a2bb8b035',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#       'team': {'id': '5cec9ee5e21b841b49026d58'}}]},
#    {'summary': 'story',
#     'estimates': 3.0,
#     'azureId': '63',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0d6',
#     'parentId': '6756b1da216f0c3a2bb8b035'},
#    {'summary': 'CRM to DWH scripts-',
#     'estimates': 8.0,
#     'azureId': '69',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0d7',
#     'parentId': '6756b1da216f0c3a2bb8b035',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'New Team story',
#     'estimates': 0.0,
#     'azureId': '176',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0e3',
#     'parentId': '6756b1da216f0c3a2bb8b035'},
#    {'summary': 'NGNIX Gateway',
#     'estimates': 3.0,
#     'azureId': '179',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0eb',
#     'parentId': '6756b1da216f0c3a2bb8b035'}]},
#  {'kendisId': '6756b1da216f0c3a2bb8b036',
#   'children': [{'summary': 'CRM Backend script updates',
#     'estimates': 8.0,
#     'azureId': '194',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1db216f0c3a2bb8b05f',
#     'parentId': '6756b1da216f0c3a2bb8b036',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#       'team': {'id': '5cec9ee5e21b841b49026d58'}}]},
#    {'summary': 'Demo Story',
#     'estimates': 0.0,
#     'azureId': '92',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b073',
#     'parentId': '6756b1da216f0c3a2bb8b036',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#    {'summary': 'Nightly sync scripts initial design',
#     'estimates': 0.0,
#     'azureId': '12',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b07a',
#     'parentId': '6756b1da216f0c3a2bb8b036',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'Scope test',
#     'estimates': 5.0,
#     'azureId': '361',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b082',
#     'parentId': '6756b1da216f0c3a2bb8b036',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'CRM system checks2',
#     'estimates': 13.0,
#     'azureId': '362',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b084',
#     'parentId': '6756b1da216f0c3a2bb8b036',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'New things',
#     'estimates': 8.0,
#     'azureId': '363',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b085',
#     'parentId': '6756b1da216f0c3a2bb8b036',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'Test',
#     'estimates': 3.0,
#     'azureId': '132',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b09c',
#     'parentId': '6756b1da216f0c3a2bb8b036'},
#    {'summary': 'New Story',
#     'estimates': 5.0,
#     'azureId': '418',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0a1',
#     'parentId': '6756b1da216f0c3a2bb8b036',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'Test item',
#     'estimates': 5.0,
#     'azureId': '386',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0ac',
#     'parentId': '6756b1da216f0c3a2bb8b036'},
#    {'summary': 'New addition',
#     'estimates': 5.0,
#     'azureId': '282',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0ca',
#     'parentId': '6756b1da216f0c3a2bb8b036',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'New one',
#     'estimates': 8.0,
#     'azureId': '169',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0d1',
#     'parentId': '6756b1da216f0c3a2bb8b036',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'New 1',
#     'estimates': 5.0,
#     'azureId': '170',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0d9',
#     'parentId': '6756b1da216f0c3a2bb8b036',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'Vendor Delivery',
#     'estimates': 0.0,
#     'azureId': '338',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0f2',
#     'parentId': '6756b1da216f0c3a2bb8b036',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'Product updates for automation script',
#     'estimates': 8.0,
#     'azureId': '73',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeab'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0f8',
#     'parentId': '6756b1da216f0c3a2bb8b036'},
#    {'summary': 'Test',
#     'estimates': 0.0,
#     'azureId': '74',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeab'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0f9',
#     'parentId': '6756b1da216f0c3a2bb8b036'},
#    {'summary': 'Green story',
#     'estimates': 3.0,
#     'azureId': '180',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0fd',
#     'parentId': '6756b1da216f0c3a2bb8b036'},
#    {'summary': 'CRM updates',
#     'estimates': 5.0,
#     'azureId': '220',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeab'},
#     'kendisId': '6756b1dc216f0c3a2bb8b100',
#     'parentId': '6756b1da216f0c3a2bb8b036',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'new 2',
#     'estimates': 20.0,
#     'azureId': '221',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dd216f0c3a2bb8b102',
#     'parentId': '6756b1da216f0c3a2bb8b036',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '64748ba7200f9f7d32f94741'}}]},
#    {'summary': 'Rolling up ',
#     'estimates': 3.0,
#     'azureId': '188',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dd216f0c3a2bb8b104',
#     'parentId': '6756b1da216f0c3a2bb8b036',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#    {'summary': 'test',
#     'estimates': 0.0,
#     'azureId': '104',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dd216f0c3a2bb8b10f',
#     'parentId': '6756b1da216f0c3a2bb8b036'},
#    {'summary': 'Team Story 2',
#     'estimates': 8.5,
#     'azureId': '80',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeab'},
#     'kendisId': '6756b1dd216f0c3a2bb8b114',
#     'parentId': '6756b1da216f0c3a2bb8b036',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]}]},
#  {'kendisId': '6756b1db216f0c3a2bb8b037',
#   'children': [{'summary': 'My story work',
#     'estimates': 0.0,
#     'azureId': '89',
#     'status': {'id': '6756b1b1216f0c3a2bb8aead'},
#     'kendisId': '6756b1db216f0c3a2bb8b059',
#     'parentId': '6756b1db216f0c3a2bb8b037'},
#    {'summary': 'New story',
#     'estimates': 13.0,
#     'azureId': '232',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1db216f0c3a2bb8b066',
#     'parentId': '6756b1db216f0c3a2bb8b037',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'New Item 2',
#     'estimates': 0.0,
#     'azureId': '90',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1db216f0c3a2bb8b06f',
#     'parentId': '6756b1db216f0c3a2bb8b037'},
#    {'summary': 'Testing 2-way things',
#     'estimates': 0.0,
#     'azureId': '91',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b072',
#     'parentId': '6756b1db216f0c3a2bb8b037'},
#    {'summary': 'Another story',
#     'estimates': 5.0,
#     'azureId': '20',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeab'},
#     'kendisId': '6756b1dc216f0c3a2bb8b091',
#     'parentId': '6756b1db216f0c3a2bb8b037',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#    {'summary': 'Team storyxxxxx',
#     'estimates': 3.0,
#     'azureId': '21',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b093',
#     'parentId': '6756b1db216f0c3a2bb8b037'},
#    {'summary': 'Another story',
#     'estimates': 8.0,
#     'azureId': '22',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b094',
#     'parentId': '6756b1db216f0c3a2bb8b037',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'Team story',
#     'estimates': 8.0,
#     'azureId': '25',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b095',
#     'parentId': '6756b1db216f0c3a2bb8b037',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#    {'summary': 'Test story',
#     'estimates': 5.0,
#     'azureId': '39',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeab'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0a4',
#     'parentId': '6756b1db216f0c3a2bb8b037',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'Testing',
#     'estimates': 5.0,
#     'azureId': '46',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0b9',
#     'parentId': '6756b1db216f0c3a2bb8b037'},
#    {'summary': 'Check Remove',
#     'estimates': 0.0,
#     'azureId': '281',
#     'status': {'id': '6756b1b1216f0c3a2bb8aead'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0c9',
#     'parentId': '6756b1db216f0c3a2bb8b037'},
#    {'summary': 'API management',
#     'estimates': 3.0,
#     'azureId': '177',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0e5',
#     'parentId': '6756b1db216f0c3a2bb8b037'},
#    {'summary': 'Migrate to IPC',
#     'estimates': 5.0,
#     'azureId': '178',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0e8',
#     'parentId': '6756b1db216f0c3a2bb8b037',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'test',
#     'estimates': 0.0,
#     'azureId': '75',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeaa'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0fa',
#     'parentId': '6756b1db216f0c3a2bb8b037'}]},
#  {'kendisId': '6756b1db216f0c3a2bb8b038',
#   'children': [{'summary': 'Frontend work',
#     'estimates': 5.0,
#     'azureId': '97',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeaa'},
#     'kendisId': '6756b1dc216f0c3a2bb8b076',
#     'parentId': '6756b1db216f0c3a2bb8b038',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#    {'summary': 'Automation for checkout experience',
#     'estimates': 13.0,
#     'azureId': '72',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeab'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0f6',
#     'parentId': '6756b1db216f0c3a2bb8b038',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#    {'summary': 'Integration to shopping cart',
#     'estimates': 8.0,
#     'azureId': '76',
#     'status': {'id': '6756b1b1216f0c3a2bb8aead'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0fb',
#     'parentId': '6756b1db216f0c3a2bb8b038'}]},
#  {'kendisId': '6756b1db216f0c3a2bb8b039',
#   'children': [{'summary': 'Billing data export to DWH',
#     'estimates': 13.0,
#     'azureId': '15',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeab'},
#     'kendisId': '6756b1dc216f0c3a2bb8b07c',
#     'parentId': '6756b1db216f0c3a2bb8b039',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'Sync script to billing',
#     'estimates': 0.0,
#     'azureId': '16',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b07d',
#     'parentId': '6756b1db216f0c3a2bb8b039',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#    {'summary': 'CRM sync for billing',
#     'estimates': 0.0,
#     'azureId': '17',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b07f',
#     'parentId': '6756b1db216f0c3a2bb8b039'},
#    {'summary': 'Story for Sky Sprint 1',
#     'estimates': 5.0,
#     'azureId': '263',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0a5',
#     'parentId': '6756b1db216f0c3a2bb8b039',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'New Story',
#     'estimates': 5.0,
#     'azureId': '309',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0b7',
#     'parentId': '6756b1db216f0c3a2bb8b039',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'New Items',
#     'estimates': 0.0,
#     'azureId': '393',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0c0',
#     'parentId': '6756b1db216f0c3a2bb8b039',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'This is a long text of the story to see how it appears on the things and many more things to test',
#     'estimates': 5.0,
#     'azureId': '203',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeaa'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0d2',
#     'parentId': '6756b1db216f0c3a2bb8b039',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'Billing Data',
#     'estimates': 5.0,
#     'azureId': '61',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0d5',
#     'parentId': '6756b1db216f0c3a2bb8b039'},
#    {'summary': 'Test',
#     'estimates': 8.0,
#     'azureId': '340',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0fe',
#     'parentId': '6756b1db216f0c3a2bb8b039',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'My demo new story',
#     'estimates': 0.0,
#     'azureId': '344',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dd216f0c3a2bb8b10a',
#     'parentId': '6756b1db216f0c3a2bb8b039'},
#    {'summary': 'test 2',
#     'estimates': 13.0,
#     'azureId': '347',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dd216f0c3a2bb8b112',
#     'parentId': '6756b1db216f0c3a2bb8b039'},
#    {'summary': 'new 1',
#     'estimates': 0.0,
#     'azureId': '348',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dd216f0c3a2bb8b113',
#     'parentId': '6756b1db216f0c3a2bb8b039'}]},
#  {'kendisId': '6756b1db216f0c3a2bb8b03a',
#   'children': [{'summary': 'Backend work',
#     'estimates': 8.0,
#     'azureId': '353',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1db216f0c3a2bb8b068',
#     'parentId': '6756b1db216f0c3a2bb8b03a'},
#    {'summary': 'Search UI mockups',
#     'estimates': 8.0,
#     'azureId': '18',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b080',
#     'parentId': '6756b1db216f0c3a2bb8b03a'},
#    {'summary': 'Team story ',
#     'estimates': 3.0,
#     'azureId': '26',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b096',
#     'parentId': '6756b1db216f0c3a2bb8b03a'},
#    {'summary': 'Fixed?',
#     'estimates': 1.0,
#     'azureId': '312',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0c6',
#     'parentId': '6756b1db216f0c3a2bb8b03a'},
#    {'summary': 'sss',
#     'estimates': 2.0,
#     'azureId': '51',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeab'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0c8',
#     'parentId': '6756b1db216f0c3a2bb8b03a'},
#    {'summary': 'at Objectives',
#     'estimates': 3.0,
#     'azureId': '204',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeaa'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0d3',
#     'parentId': '6756b1db216f0c3a2bb8b03a',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'Team story 1',
#     'estimates': 3.0,
#     'azureId': '77',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0fc',
#     'parentId': '6756b1db216f0c3a2bb8b03a'}]},
#  {'kendisId': '6756b1db216f0c3a2bb8b03b',
#   'children': [{'summary': 'My demo story 2',
#     'estimates': 0.0,
#     'azureId': '193',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1db216f0c3a2bb8b05d',
#     'parentId': '6756b1db216f0c3a2bb8b03b',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#    {'summary': 'New Story',
#     'estimates': 5.0,
#     'azureId': '119',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b075',
#     'parentId': '6756b1db216f0c3a2bb8b03b'},
#    {'summary': 'Test story',
#     'estimates': 5.0,
#     'azureId': '124',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b08b',
#     'parentId': '6756b1db216f0c3a2bb8b03b'},
#    {'summary': 'New Story',
#     'estimates': 3.0,
#     'azureId': '155',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeaa'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0c3',
#     'parentId': '6756b1db216f0c3a2bb8b03b',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#    {'summary': 'New Stuff',
#     'estimates': 13.0,
#     'azureId': '317',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0c7',
#     'parentId': '6756b1db216f0c3a2bb8b03b'}]},
#  {'kendisId': '6756b1db216f0c3a2bb8b03c'},
#  {'kendisId': '6756b1db216f0c3a2bb8b03d',
#   'children': [{'summary': 'Team story',
#     'estimates': 3.0,
#     'azureId': '111',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1db216f0c3a2bb8b069',
#     'parentId': '6756b1db216f0c3a2bb8b03d'},
#    {'summary': 'Team A',
#     'estimates': 5.0,
#     'azureId': '112',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1db216f0c3a2bb8b06a',
#     'parentId': '6756b1db216f0c3a2bb8b03d'},
#    {'summary': 'test 2',
#     'estimates': 8.0,
#     'azureId': '355',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1db216f0c3a2bb8b06b',
#     'parentId': '6756b1db216f0c3a2bb8b03d',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'Demo Story 2',
#     'estimates': 5.0,
#     'azureId': '117',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeaa'},
#     'kendisId': '6756b1db216f0c3a2bb8b070',
#     'parentId': '6756b1db216f0c3a2bb8b03d'},
#    {'summary': 'Should be at number 3',
#     'estimates': 8.0,
#     'azureId': '250',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b098',
#     'parentId': '6756b1db216f0c3a2bb8b03d',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'Search Management',
#     'estimates': 5.0,
#     'azureId': '133',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b09d',
#     'parentId': '6756b1db216f0c3a2bb8b03d'},
#    {'summary': 'System Updates',
#     'estimates': 0.0,
#     'azureId': '391',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0bd',
#     'parentId': '6756b1db216f0c3a2bb8b03d'},
#    {'summary': 'Story for Feature 96',
#     'estimates': 8.0,
#     'azureId': '392',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0be',
#     'parentId': '6756b1db216f0c3a2bb8b03d',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'test',
#     'estimates': 0.0,
#     'azureId': '167',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0cf',
#     'parentId': '6756b1db216f0c3a2bb8b03d',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'New Story',
#     'estimates': 0.0,
#     'azureId': '168',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeaa'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0d0',
#     'parentId': '6756b1db216f0c3a2bb8b03d',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]}]},
#  {'kendisId': '6756b1db216f0c3a2bb8b03e',
#   'children': [{'summary': 'Story 1',
#     'estimates': 5.0,
#     'azureId': '335',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0ef',
#     'parentId': '6756b1db216f0c3a2bb8b03e',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]}]},
#  {'kendisId': '6756b1db216f0c3a2bb8b03f',
#   'children': [{'summary': 'team storyxccvv',
#     'estimates': 13.0,
#     'azureId': '122',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeab'},
#     'kendisId': '6756b1dc216f0c3a2bb8b088',
#     'parentId': '6756b1db216f0c3a2bb8b03f',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'Tiger story',
#     'estimates': 5.0,
#     'azureId': '123',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b08a',
#     'parentId': '6756b1db216f0c3a2bb8b03f'},
#    {'summary': 'T sto',
#     'estimates': 5.0,
#     'azureId': '126',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeab'},
#     'kendisId': '6756b1dc216f0c3a2bb8b08d',
#     'parentId': '6756b1db216f0c3a2bb8b03f'},
#    {'summary': 'GW Enhancements',
#     'estimates': 5.0,
#     'azureId': '308',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0b5',
#     'parentId': '6756b1db216f0c3a2bb8b03f',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#    {'summary': 'Story that should be done first',
#     'estimates': 8.0,
#     'azureId': '163',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0cd',
#     'parentId': '6756b1db216f0c3a2bb8b03f',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#       'team': {'id': '5cec9ee5e21b841b49026d58'}}]},
#    {'summary': 'Demo 5',
#     'estimates': 8.0,
#     'azureId': '292',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeaa'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0dc',
#     'parentId': '6756b1db216f0c3a2bb8b03f',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]},
#    {'summary': 'Test my story',
#     'estimates': 0.0,
#     'azureId': '102',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dd216f0c3a2bb8b10b',
#     'parentId': '6756b1db216f0c3a2bb8b03f'},
#    {'summary': 'New story 2',
#     'estimates': 0.0,
#     'azureId': '103',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dd216f0c3a2bb8b10c',
#     'parentId': '6756b1db216f0c3a2bb8b03f'}]},
#  {'kendisId': '6756b1db216f0c3a2bb8b040',
#   'children': [{'summary': 'Demo story for feature 09',
#     'estimates': 5.0,
#     'azureId': '334',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0ec',
#     'parentId': '6756b1db216f0c3a2bb8b040',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#    {'summary': 'Story for my feature',
#     'estimates': 5.0,
#     'azureId': '109',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dd216f0c3a2bb8b115',
#     'parentId': '6756b1db216f0c3a2bb8b040',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefd'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]}]},
#  {'kendisId': '6756b1db216f0c3a2bb8b041',
#   'children': [{'summary': 'CRM System',
#     'estimates': 8.0,
#     'azureId': '385',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0a9',
#     'parentId': '6756b1db216f0c3a2bb8b041',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefb'},
#       'team': {'id': '60edb734e48f063fb84f4094'}}]}]},
#  {'kendisId': '6756b1db216f0c3a2bb8b042',
#   'children': [{'summary': 'New Story ',
#     'estimates': 5.0,
#     'azureId': '339',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0f4',
#     'parentId': '6756b1db216f0c3a2bb8b042',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefa'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]}]},
#  {'kendisId': '6756b1db216f0c3a2bb8b043'},
#  {'kendisId': '6756b1db216f0c3a2bb8b044'},
#  {'kendisId': '6756b1db216f0c3a2bb8b045'},
#  {'kendisId': '6756b1db216f0c3a2bb8b046',
#   'children': [{'summary': 'test',
#     'estimates': 0.0,
#     'azureId': '191',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1db216f0c3a2bb8b05a',
#     'parentId': '6756b1db216f0c3a2bb8b046',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '5cec9ee5e21b841b49026d58'}}]},
#    {'summary': 'Demo 2',
#     'estimates': 0.0,
#     'azureId': '192',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1db216f0c3a2bb8b05c',
#     'parentId': '6756b1db216f0c3a2bb8b046'},
#    {'summary': 'New Story for TW team',
#     'estimates': 5.0,
#     'azureId': '298',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0e6',
#     'parentId': '6756b1db216f0c3a2bb8b046',
#     'teamsAndSprints': [{'sprint': {'id': '6756b1b1216f0c3a2bb8aefc'},
#       'team': {'id': '5cec9ef2e21b841b49026d5b'}}]},
#    {'summary': 'story 1',
#     'estimates': 0.0,
#     'azureId': '216',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0f1',
#     'parentId': '6756b1db216f0c3a2bb8b046'},
#    {'summary': 'Test 2',
#     'estimates': 0.0,
#     'azureId': '189',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dd216f0c3a2bb8b107',
#     'parentId': '6756b1db216f0c3a2bb8b046'}]},
#  {'kendisId': '6756b1db216f0c3a2bb8b047',
#   'children': [{'summary': 'Test',
#     'estimates': 5.0,
#     'azureId': '296',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0e2',
#     'parentId': '6756b1db216f0c3a2bb8b047'},
#    {'summary': 'Another one',
#     'estimates': 13.0,
#     'azureId': '297',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1dc216f0c3a2bb8b0e4',
#     'parentId': '6756b1db216f0c3a2bb8b047'}]},
#  {'kendisId': '6756b1db216f0c3a2bb8b048',
#   'children': [{'summary': 'Test story for univ2',
#     'estimates': 0.0,
#     'azureId': '357',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1db216f0c3a2bb8b06d',
#     'parentId': '6756b1db216f0c3a2bb8b048'},
#    {'summary': 'univ3 - for sprint univ2-2',
#     'estimates': 0.0,
#     'azureId': '358',
#     'status': {'id': '6756b1b1216f0c3a2bb8aea9'},
#     'kendisId': '6756b1db216f0c3a2bb8b06e',
#     'parentId': '6756b1db216f0c3a2bb8b048'},
#    {'summary': 'For testing Univ2-2 multi path',
#     'estimates': 0.0,
#     'azureId': '359',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1db216f0c3a2bb8b071',
#     'parentId': '6756b1db216f0c3a2bb8b048'},
#    {'summary': 'test 44444',
#     'estimates': 0.0,
#     'azureId': '360',
#     'status': {'id': '6756b1b1216f0c3a2bb8aeac'},
#     'kendisId': '6756b1dc216f0c3a2bb8b081',
#     'parentId': '6756b1db216f0c3a2bb8b048'}]}]

# %%
# Example Request 3: If users want only selective fields they can use the following format in Body as JSON

import json
import requests

url = 'https://rest.kendis.io/api/example/items'
# Define the body as a Python dictionary
payload = {
    "boardId":"6756b1b0216f0c3a2bb8ae6e",
    "fields":["createdOn","cardType","itemType","iterationPath"],
    "pageStart" : 1,
    "pageSize" : 20
}

# Convert the dictionary to a raw JSON string
raw_json_body = json.dumps(payload)
# Send the GET request with Basic Auth
response = requests.post(url, data=raw_json_body, auth=(username, password), headers={"Content-Type": "application/json"})
# Check the response
if response.status_code == 200:
    # Successfully retrieved data
    items_data = response.json()  # Parse JSON response
    print("Data retrieved successfully:")
    print(items_data)
else:
    # Handle error
    print(f"Failed to retrieve data. HTTP Status Code: {response.status_code}")
    print("Response content:", response.text)
# Out:
# Data retrieved successfully:
# {'data': [{'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\TW-Sprint5.3', 'createdOn': 1733734874999, 'kendisId': '6756b1da216f0c3a2bb8b035'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\SKY-Sprint5.1', 'createdOn': 1733734875006, 'kendisId': '6756b1da216f0c3a2bb8b036'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\TW-Sprint5.1', 'createdOn': 1733734875013, 'kendisId': '6756b1db216f0c3a2bb8b037'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile', 'createdOn': 1733734875019, 'kendisId': '6756b1db216f0c3a2bb8b038'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\Iteration-1', 'createdOn': 1733734875025, 'kendisId': '6756b1db216f0c3a2bb8b039'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\TW-Sprint5.3', 'createdOn': 1733734875031, 'kendisId': '6756b1db216f0c3a2bb8b03a'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\TW-Sprint5.3', 'createdOn': 1733734875038, 'kendisId': '6756b1db216f0c3a2bb8b03b'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile', 'createdOn': 1733734875044, 'kendisId': '6756b1db216f0c3a2bb8b03c'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\A-SKY-Sprint5.4', 'createdOn': 1733734875050, 'kendisId': '6756b1db216f0c3a2bb8b03d'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\Q22024', 'createdOn': 1733734875056, 'kendisId': '6756b1db216f0c3a2bb8b03e'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile', 'createdOn': 1733734875062, 'kendisId': '6756b1db216f0c3a2bb8b03f'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\SKY-Sprint5.2', 'createdOn': 1733734875068, 'kendisId': '6756b1db216f0c3a2bb8b040'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\Iteration-1', 'createdOn': 1733734875074, 'kendisId': '6756b1db216f0c3a2bb8b041'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\Iteration-1', 'createdOn': 1733734875080, 'kendisId': '6756b1db216f0c3a2bb8b042'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile', 'createdOn': 1733734875086, 'kendisId': '6756b1db216f0c3a2bb8b043'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile', 'createdOn': 1733734875091, 'kendisId': '6756b1db216f0c3a2bb8b044'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\TGR-Sprint5.3', 'createdOn': 1733734875097, 'kendisId': '6756b1db216f0c3a2bb8b045'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile', 'createdOn': 1733734875104, 'kendisId': '6756b1db216f0c3a2bb8b046'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile\\TGR-Sprint5.3', 'createdOn': 1733734875110, 'kendisId': '6756b1db216f0c3a2bb8b047'}, {'itemType': 'Feature', 'iterationPath': 'ZAP - Agile', 'createdOn': 1733734875115, 'kendisId': '6756b1db216f0c3a2bb8b048'}]}

# %%
items_data['data']
# Out:
# [{'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\TW-Sprint5.3',
#   'createdOn': 1733734874999,
#   'kendisId': '6756b1da216f0c3a2bb8b035'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\SKY-Sprint5.1',
#   'createdOn': 1733734875006,
#   'kendisId': '6756b1da216f0c3a2bb8b036'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\TW-Sprint5.1',
#   'createdOn': 1733734875013,
#   'kendisId': '6756b1db216f0c3a2bb8b037'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'createdOn': 1733734875019,
#   'kendisId': '6756b1db216f0c3a2bb8b038'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\Iteration-1',
#   'createdOn': 1733734875025,
#   'kendisId': '6756b1db216f0c3a2bb8b039'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\TW-Sprint5.3',
#   'createdOn': 1733734875031,
#   'kendisId': '6756b1db216f0c3a2bb8b03a'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\TW-Sprint5.3',
#   'createdOn': 1733734875038,
#   'kendisId': '6756b1db216f0c3a2bb8b03b'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'createdOn': 1733734875044,
#   'kendisId': '6756b1db216f0c3a2bb8b03c'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\A-SKY-Sprint5.4',
#   'createdOn': 1733734875050,
#   'kendisId': '6756b1db216f0c3a2bb8b03d'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\Q22024',
#   'createdOn': 1733734875056,
#   'kendisId': '6756b1db216f0c3a2bb8b03e'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'createdOn': 1733734875062,
#   'kendisId': '6756b1db216f0c3a2bb8b03f'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\SKY-Sprint5.2',
#   'createdOn': 1733734875068,
#   'kendisId': '6756b1db216f0c3a2bb8b040'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\Iteration-1',
#   'createdOn': 1733734875074,
#   'kendisId': '6756b1db216f0c3a2bb8b041'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\Iteration-1',
#   'createdOn': 1733734875080,
#   'kendisId': '6756b1db216f0c3a2bb8b042'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'createdOn': 1733734875086,
#   'kendisId': '6756b1db216f0c3a2bb8b043'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'createdOn': 1733734875091,
#   'kendisId': '6756b1db216f0c3a2bb8b044'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\TGR-Sprint5.3',
#   'createdOn': 1733734875097,
#   'kendisId': '6756b1db216f0c3a2bb8b045'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'createdOn': 1733734875104,
#   'kendisId': '6756b1db216f0c3a2bb8b046'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile\\TGR-Sprint5.3',
#   'createdOn': 1733734875110,
#   'kendisId': '6756b1db216f0c3a2bb8b047'},
#  {'itemType': 'Feature',
#   'iterationPath': 'ZAP - Agile',
#   'createdOn': 1733734875115,
#   'kendisId': '6756b1db216f0c3a2bb8b048'}]

# %% [markdown]
# ### 2. Retrieve Meta for Sprints

# %%
# Example Request 4

import json
import requests

url = 'https://rest.kendis.io/api/example/sprints'
# Define the body as a Python dictionary
payload = {
    "boardId":"6756b1b0216f0c3a2bb8ae6e"
}

# Convert the dictionary to a raw JSON string
raw_json_body = json.dumps(payload)
# Send the GET request with Basic Auth
response = requests.post(url, data=raw_json_body, auth=(username, password), headers={"Content-Type": "application/json"})
# Check the response
if response.status_code == 200:
    # Successfully retrieved data
    items_data = response.json()  # Parse JSON response
    print("Data retrieved successfully:")
    print(items_data)
else:
    # Handle error
    print(f"Failed to retrieve data. HTTP Status Code: {response.status_code}")
    print("Response content:", response.text)
# Out:
# Data retrieved successfully:
# {'data': [{'id': '6756b1b1216f0c3a2bb8aefa', 'label': '5.1', 'title': 'Iteration 5.1', 'isIPSprint': False}, {'id': '6756b1b1216f0c3a2bb8aefb', 'label': '5.2', 'title': 'Iteration 5.2', 'isIPSprint': False}, {'id': '6756b1b1216f0c3a2bb8aefc', 'label': '5.3', 'title': 'Iteration 5.3', 'isIPSprint': False}, {'id': '6756b1b1216f0c3a2bb8aefd', 'label': '5.4', 'title': 'Iteration 5.4', 'isIPSprint': False}]}

# %%
items_data['data']
# Out:
# [{'id': '6756b1b1216f0c3a2bb8aefa',
#   'label': '5.1',
#   'title': 'Iteration 5.1',
#   'isIPSprint': False},
#  {'id': '6756b1b1216f0c3a2bb8aefb',
#   'label': '5.2',
#   'title': 'Iteration 5.2',
#   'isIPSprint': False},
#  {'id': '6756b1b1216f0c3a2bb8aefc',
#   'label': '5.3',
#   'title': 'Iteration 5.3',
#   'isIPSprint': False},
#  {'id': '6756b1b1216f0c3a2bb8aefd',
#   'label': '5.4',
#   'title': 'Iteration 5.4',
#   'isIPSprint': False}]

# %% [markdown]
# ### 3. Retrieve Meta for Teams

# %%
# Example Request 5

import json
import requests

url = 'https://rest.kendis.io/api/example/teams'
# Define the body as a Python dictionary
payload = {
    "boardId":"6756b1b0216f0c3a2bb8ae6e"
}

# Convert the dictionary to a raw JSON string
raw_json_body = json.dumps(payload)
# Send the GET request with Basic Auth
response = requests.post(url, data=raw_json_body, auth=(username, password), headers={"Content-Type": "application/json"})
# Check the response
if response.status_code == 200:
    # Successfully retrieved data
    items_data = response.json()  # Parse JSON response
    print("Data retrieved successfully:")
    print(items_data)
else:
    # Handle error
    print(f"Failed to retrieve data. HTTP Status Code: {response.status_code}")
    print("Response content:", response.text)
# Out:
# Data retrieved successfully:
# {'data': [{'color': '#e87e04', 'id': '5cec9edae21b841b49026d57', 'label': 'CRM', 'title': 'Team CRM'}, {'color': '#6b47db', 'id': '5cec9ee5e21b841b49026d58', 'label': 'DWH', 'title': 'Team DWH'}, {'color': '#c0392b', 'id': '5cec9ef2e21b841b49026d5b', 'label': 'TW', 'title': 'Team Whale'}, {'color': '#6b47db', 'id': '5cec9f06e21b841b49026d5d', 'label': '3P', 'title': 'Third Party'}, {'color': '#f9bf3b', 'id': '60edb734e48f063fb84f4094', 'label': 'ORD', 'title': 'Other RT Dependencies'}, {'color': '#3a539b', 'id': '64748ba7200f9f7d32f94741', 'label': 'RTS', 'title': 'RTS Team'}]}

# %%
items_data['data']
# Out:
# [{'color': '#e87e04',
#   'id': '5cec9edae21b841b49026d57',
#   'label': 'CRM',
#   'title': 'Team CRM'},
#  {'color': '#6b47db',
#   'id': '5cec9ee5e21b841b49026d58',
#   'label': 'DWH',
#   'title': 'Team DWH'},
#  {'color': '#c0392b',
#   'id': '5cec9ef2e21b841b49026d5b',
#   'label': 'TW',
#   'title': 'Team Whale'},
#  {'color': '#6b47db',
#   'id': '5cec9f06e21b841b49026d5d',
#   'label': '3P',
#   'title': 'Third Party'},
#  {'color': '#f9bf3b',
#   'id': '60edb734e48f063fb84f4094',
#   'label': 'ORD',
#   'title': 'Other RT Dependencies'},
#  {'color': '#3a539b',
#   'id': '64748ba7200f9f7d32f94741',
#   'label': 'RTS',
#   'title': 'RTS Team'}]

# %% [markdown]
# ### 4. Retrieve Meta for Statuses

# %%
# Example Request 6:

import json
import requests

url = 'https://rest.kendis.io/api/example/statuses'
# Define the body as a Python dictionary
payload = {
    "boardId":"6756b1b0216f0c3a2bb8ae6e"
}

# Convert the dictionary to a raw JSON string
raw_json_body = json.dumps(payload)
# Send the GET request with Basic Auth
response = requests.post(url, data=raw_json_body, auth=(username, password), headers={"Content-Type": "application/json"})
# Check the response
if response.status_code == 200:
    # Successfully retrieved data
    items_data = response.json()  # Parse JSON response
    print("Data retrieved successfully:")
    print(items_data)
else:
    # Handle error
    print(f"Failed to retrieve data. HTTP Status Code: {response.status_code}")
    print("Response content:", response.text)
# Out:
# Data retrieved successfully:
# {'data': {'parentStatuses': [{'id': '5cec9d67e21b841b49026cef', 'rowStatus': 0, 'source': 0, 'title': 'Open', 'category': 'ToDo', 'updated': False}, {'id': '5cec9d67e21b841b49026cf0', 'rowStatus': 0, 'source': 0, 'title': 'In Progress', 'category': 'InProgress', 'updated': False}, {'id': '5cec9d67e21b841b49026cf1', 'rowStatus': 0, 'source': 0, 'title': 'Done', 'category': 'Done', 'updated': False}], 'childrenStatuses': [{'id': '5cec9d67e21b841b49026cef', 'rowStatus': 0, 'source': 0, 'title': 'Open', 'category': 'ToDo', 'updated': False}, {'id': '5cec9d67e21b841b49026cf0', 'rowStatus': 0, 'source': 0, 'title': 'In Progress', 'category': 'InProgress', 'updated': False}, {'id': '5cec9d67e21b841b49026cf1', 'rowStatus': 0, 'source': 0, 'title': 'Done', 'category': 'Done', 'updated': False}]}}

# %%
items_data['data']
# Out:
# {'parentStatuses': [{'id': '5cec9d67e21b841b49026cef',
#    'rowStatus': 0,
#    'source': 0,
#    'title': 'Open',
#    'category': 'ToDo',
#    'updated': False},
#   {'id': '5cec9d67e21b841b49026cf0',
#    'rowStatus': 0,
#    'source': 0,
#    'title': 'In Progress',
#    'category': 'InProgress',
#    'updated': False},
#   {'id': '5cec9d67e21b841b49026cf1',
#    'rowStatus': 0,
#    'source': 0,
#    'title': 'Done',
#    'category': 'Done',
#    'updated': False}],
#  'childrenStatuses': [{'id': '5cec9d67e21b841b49026cef',
#    'rowStatus': 0,
#    'source': 0,
#    'title': 'Open',
#    'category': 'ToDo',
#    'updated': False},
#   {'id': '5cec9d67e21b841b49026cf0',
#    'rowStatus': 0,
#    'source': 0,
#    'title': 'In Progress',
#    'category': 'InProgress',
#    'updated': False},
#   {'id': '5cec9d67e21b841b49026cf1',
#    'rowStatus': 0,
#    'source': 0,
#    'title': 'Done',
#    'category': 'Done',
#    'updated': False}]}
